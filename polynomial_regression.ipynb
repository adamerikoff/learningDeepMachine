# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Generate random data points
np.random.seed(0)
x = np.random.uniform(-2, 2, 40)  # Generate 30 random x values
y = 2 * x**3 - 3 * x**2 + x - 1 + np.random.normal(0, 2, 40)  # Generate corresponding noisy y values

# Reshape x to a column vector
x = x.reshape(-1, 1)

# Create the scatter plot of the data points
plt.figure(figsize=(8, 6))
plt.scatter(x, y, label='Data', color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter Plot')
plt.grid(True)
plt.legend()
plt.show()

# %%
def polynimial_regression(x, y, degree):
