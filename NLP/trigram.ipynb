# %%
texte = """
    Here's the text with the quotes removed:

October arrived, spreading a damp chill over the grounds and into the castle. Madam Pomfrey, the nurse, was kept busy by a sudden spate of colds among the staff and students. Her Pepperup potion worked instantly, though it left the drinker smoking at the ears for several hours afterward. Ginny Weasley, who had been looking pale, was bullied into taking some by Percy. The steam pouring from under her vivid hair gave the impression that her whole head was on fire.

Raindrops the size of bullets thundered on the castle windows for days on end; the lake rose, the flower beds turned into muddy streams, and Hagrid's pumpkins swelled to the size of garden sheds. Oliver Wood's enthusiasm for regular training sessions, however, was not dampened, which was why Harry was to be found, late one stormy Saturday afternoon a few days before Halloween, returning to Gryffindor Tower, drenched to the skin and splattered with mud.

Even aside from the rain and wind it hadn't been a happy practice session. Fred and George, who had been spying on the Slytherin team, had seen for themselves the speed of those new Nimbus Two Thousand and Ones. They reported that the Slytherin team was no more than seven greenish blurs, shooting through the air like missiles.

As Harry squelched along the deserted corridor he came across somebody who looked just as preoccupied as he was. Nearly Headless Nick, the ghost of Gryffindor Tower, was staring morosely out of a window, muttering under his breath, . . . don't fulfill their requirements . . . half an inch, if that . . .

Hello, Nick, said Harry.

Hello, hello, said Nearly Headless Nick, starting and looking round. He wore a dashing, plumed hat on his long curly hair, and a tunic with a ruff, which concealed the fact that his neck was almost completely severed. He was pale as smoke, and Harry could see right through him to the dark sky and torrential rain outside.

You look troubled, young Potter, said Nick, folding a transparent letter as he spoke and tucking it inside his doublet.

So do you, said Harry.

Ah, Nearly Headless Nick waved an elegant hand, a matter of no importance. . . . It's not as though I really wanted to join. . . . Thought I'd apply, but apparently I don't fulfill requirements -

In spite of his airy tone, there was a look of great bitterness on his face.

But you would think, wouldn't you, he erupted suddenly, pulling the letter back out of his pocket, that getting hit forty-five times in the neck with a blunt axe would qualify you to join the Headless Hunt?

Oh - yes, said Harry, who was obviously supposed to agree.

I mean, nobody wishes more than I do that it had all been quick and clean, and my head had come off properly, I mean, it would have saved me a great deal of pain and ridicule. However - Nearly Headless Nick shook his letter open and read furiously: We can only accept huntsmen whose heads have parted company with their bodies. You will appreciate that it would be impossible otherwise for members to participate in hunt activities such as Horseback Head-Juggling and Head Polo. It is with the greatest regret, therefore, that I must inform you that you do not fulfill our requirements. With very best wishes, Sir Patrick Delaney-Podmore.

Fuming, Nearly Headless Nick stuffed the letter away.

Half an inch of skin and sinew holding my neck on, Harry! Most people would think that's good and beheaded, but oh, no, it's not enough for Sir Properly Decapitated-Podmore.

Nearly Headless Nick took several deep breaths and then said, in a far calmer tone, So - what's bothering you? Anything I can do?

No, said Harry. Not unless you know where we can get seven free Nimbus Two Thousand and Ones for our match against Sly -

The rest of Harry's sentence was drowned out by a high-pitched mewling from somewhere near his ankles. He looked down and found himself gazing into a pair of lamp-like yellow eyes. It was Mrs. Norris, the skeletal gray cat who was used by the caretaker, Argus Filch, as a sort of deputy in his endless battle against students.

You'd better get out of here, Harry, said Nick quickly. Filch isn't in a good mood - he's got the flu and some third years accidentally plastered frog brains all over the ceiling in dungeon five. He's been cleaning all morning, and if he sees you dripping mud all over the place -

Right, said Harry, backing away from the accusing stare of Mrs. Norris, but not quickly enough. Drawn to the spot by the mysterious power that seemed to connect him with his foul cat, Argus Filch burst suddenly through a tapestry to Harry's right, wheezing and looking wildly about for the rule-breaker. There was a thick tartan scarf bound around his head, and his nose was unusually purple.

Filth! he shouted, his jowls aquiver, his eyes popping alarmingly as he pointed at the muddy puddle that had dripped from Harry's Quidditch robes. Mess and muck everywhere! I've had enough of it, I tell you! Follow me, Potter!

So Harry waved a gloomy good-bye to Nearly Headless Nick and followed Filch back downstairs, doubling the number of muddy footprints on the floor.

Harry had never been inside Filch's office before; it was a place most students avoided. The room was dingy and windowless, lit by a single oil lamp dangling from the low ceiling. A faint smell of fried fish lingered about the place. Wooden filing cabinets stood around the walls; from their labels, Harry could see that they contained details of every pupil Filch had ever punished. Fred and George Weasley had an entire drawer to themselves. A highly polished collection of chains and manacles hung on the wall behind Filch's desk. It was common knowledge that he was always begging Dumbledore to let him suspend students by their ankles from the ceiling.

Filch grabbed a quill from a pot on his desk and began shuffling around looking for parchment.

Dung, he muttered furiously, great sizzling dragon bogies . . . frog brains . . . rat intestines . . . I've had enough of it . . . make an example . . . where's the form . . . yes . . .

He retrieved a large roll of parchment from his desk drawer and stretched it out in front of him, dipping his long black quill into the ink pot.

Name . . . Harry Potter. Crime . . .

It was only a bit of mud! said Harry.

It's only a bit of mud to you, boy, but to me it's an extra hour scrubbing! shouted Filch, a drip shivering unpleasantly at the end of his bulbous nose. Crime . . . befouling the castle . . . suggested sentence . . .

Dabbing at his streaming nose, Filch squinted unpleasantly at Harry who waited with bated breath for his sentence to fall.

But as Filch lowered his quill, there was a great BANG! on the ceiling of the office, which made the oil lamp
"""

# %%
import re
texte = texte.lower().replace("\n", ' ')
texte = re.sub('[^a-z0-9\.\-]', ' ', texte)
texte = re.sub('\s{2,}', ' ', texte)  # Suppression des espaces multiples
texte = '. ' + texte.replace('.', ' .')  # Ajout de points pour délimiter les phrases
texte = re.sub(' [a-z0-9] ', '', texte)  # Suppression des mots uniques inutiles

# %%
mots = texte.split()  # Découpe le texte en mots individuels
trigrammes = {}
bigrammes = {}  # Initialise un dictionnaire vide pour stocker les bigrammes

# %%
# Parcours de chaque paire de mots consécutifs dans le texte
for i in range(len(mots) - 2):
    mot1 = mots[i]
    mot2 = mots[i + 1]
    mot3 = mots[i + 2]

    # Vérifie si mot1 est déjà une clé dans bigrammes
    if not mot1 in bigrammes:
        # Si non, ajoute mot1 comme clé avec une valeur de dictionnaire vide
        bigrammes[mot1] = {}
        
    # Vérifie si mot2 est déjà une clé dans le dictionnaire associé à mot1
    if mot2 in bigrammes[mot1]:
        # Si non, initialise le compteur de mot2 à 1
        bigrammes[mot1][mot2] += 1
    else:
        # Si oui, incrémente le compteur de mot2 de 1
        bigrammes[mot1][mot2] = 1
    
    if not (mot1, mot2) in trigrammes:
        trigrammes[(mot1, mot2)] = {} 
    
    if mot3 in trigrammes[(mot1, mot2)]:
        # If not, initialize the count of mot3 to 1
        trigrammes[(mot1, mot2)][mot3] += 1
    else:
        # If yes, increment the count of mot3 by 1
        trigrammes[(mot1, mot2)][mot3] = 1

# %%
# Parcours de chaque mot clé dans bigrammes
for mot in bigrammes:
    # Trie le dictionnaire de bigrammes associé au mot actuel par leurs comptages
    bigrammes_tries = dict(sorted(bigrammes[mot].items(), key=lambda item: -item[1]))
    
    # Calcule le nombre total de tous les bigrammes associés au mot actuel
    total_comptage = sum(bigrammes_tries.values())
    
    # Normalise les comptages des bigrammes associés au mot actuel
    bigrammes_normalises = {}
    for bigramme, comptage in bigrammes_tries.items():
        comptage_normalise = comptage / total_comptage
        bigrammes_normalises[bigramme] = comptage_normalise
    
    # Met à jour bigrammes[mot] avec les comptages normalisés des bigrammes
    bigrammes[mot] = bigrammes_normalises

# %%
# Parcours de chaque mot clé dans bigrammes
for mot in trigrammes:
    # Trie le dictionnaire de bigrammes associé au mot actuel par leurs comptages
    trigrammes_tries = dict(sorted(trigrammes[mot].items(), key=lambda item: -item[1]))
    
    # Calcule le nombre total de tous les bigrammes associés au mot actuel
    total_comptage = sum(trigrammes_tries.values())
    
    # Normalise les comptages des bigrammes associés au mot actuel
    trigrammes_normalises = {}
    for bigramme, comptage in trigrammes_tries.items():
        comptage_normalise = comptage / total_comptage
        trigrammes_normalises[bigramme] = comptage_normalise
    
    # Met à jour bigrammes[mot] avec les comptages normalisés des bigrammes
    trigrammes[mot] = trigrammes_normalises

# %%
import random

# Fonction pour choisir le mot suivant en fonction du mot actuel
def mot_suivant_bigrammes(mot):
    # Récupère les bigrammes associés au mot donné
    vars = bigrammes[mot]
    
    # Sélectionne aléatoirement le mot suivant en fonction des poids des bigrammes
    return random.choices(list(vars.keys()), weights=vars.values())[0]

# Fonction pour choisir le mot suivant en fonction du mot actuel
def mot_suivant_trigrammes(mot):
    # Récupère les bigrammes associés au mot donné
    vars = trigrammes[mot]
    
    # Sélectionne aléatoirement le mot suivant en fonction des poids des bigrammes
    return random.choices(list(vars.keys()), weights=vars.values())[0]

# %%
# Fonction pour générer une phrase aléatoire
def phrase():
    mots = []  # Liste pour stocker les mots de la phrase
    mots.append(mot_suivant_bigrammes('.'))
    mots.append(mot_suivant_bigrammes(mots[-1]))
    # Boucle pour générer une phrase jusqu'à ce qu'un point soit rencontré ou que 50 mots soient atteints
    for i in range(50):
        mot = mot_suivant_trigrammes(tuple(mots[-2:]))
          # Sélectionne le mot suivant en fonction du mot actuel
        if mot == '.':  # Vérifie si le mot suivant est un point, indiquant la fin de la phrase
            break
        mots.append(mot)  # Ajoute le mot suivant à la liste de mots    
    # Retourne la phrase générée avec la première lettre en majuscule
    return (' '.join(mots) + '. ').capitalize()

# %%
for i in range(10):
    print(phrase())
# Out:
# Drawn to the skin and splattered with mud.
# It was mrs.
# Wherethe form.
# Norris the skeletal gray cat who was obviously supposed to agree .mean nobody wishes more thando that it had all been quick and clean and my head had come off properlymean it would have saved megreat deal of pain and ridicule.
# . . it is with the quotes removed october arrived spreadingdamp chill over the place.
# The rule-breaker.
# . befouling the castle.
# The spot by the caretaker argus filch burst suddenly throughtapestry to harryright wheezing and looking round.
# . ah nearly headless nick the ghost of gryffindor tower was staring morosely out ofwindow muttering under his breath.
# You that you do not fulfill our requirements.

# %%
bigrammes
# Out:
# {'.': {'.': 0.3431372549019608,
#   'he': 0.0392156862745098,
#   'it': 0.0392156862745098,
#   'the': 0.0196078431372549,
#   'fred': 0.0196078431372549,
#   'nearly': 0.0196078431372549,
#   'half': 0.0196078431372549,
#   'hello': 0.0196078431372549,
#   'you': 0.0196078431372549,
#   'but': 0.0196078431372549,
#   'norris': 0.0196078431372549,
#   'filch': 0.0196078431372549,
#   'harry': 0.0196078431372549,
#   'crime': 0.0196078431372549,
#   'herethe': 0.00980392156862745,
#   'madam': 0.00980392156862745,
#   'her': 0.00980392156862745,
#   'ginny': 0.00980392156862745,
#   'raindrops': 0.00980392156862745,
#   'oliver': 0.00980392156862745,
#   'even': 0.00980392156862745,
#   'they': 0.00980392156862745,
#   'as': 0.00980392156862745,
#   'donfulfill': 0.00980392156862745,
#   'so': 0.00980392156862745,
#   'ah': 0.00980392156862745,
#   'itnot': 0.00980392156862745,
#   'thoughtd': 0.00980392156862745,
#   'however': 0.00980392156862745,
#   'with': 0.00980392156862745,
#   'fuming': 0.00980392156862745,
#   'not': 0.00980392156862745,
#   'youbetter': 0.00980392156862745,
#   'hebeen': 0.00980392156862745,
#   'drawn': 0.00980392156862745,
#   'there': 0.00980392156862745,
#   'filth': 0.00980392156862745,
#   'mess': 0.00980392156862745,
#   'wooden': 0.00980392156862745,
#   'dung': 0.00980392156862745,
#   'frog': 0.00980392156862745,
#   'rat': 0.00980392156862745,
#   '.ve': 0.00980392156862745,
#   'make': 0.00980392156862745,
#   'wherethe': 0.00980392156862745,
#   'yes': 0.00980392156862745,
#   'name': 0.00980392156862745,
#   'itonlybit': 0.00980392156862745,
#   'befouling': 0.00980392156862745,
#   'suggested': 0.00980392156862745,
#   'dabbing': 0.00980392156862745},
#  'herethe': {'text': 1.0},
#  'text': {'with': 1.0},
#  'with': {'the': 0.2857142857142857,
#   'mud': 0.14285714285714285,
#   'their': 0.14285714285714285,
#   'very': 0.14285714285714285,
#   'his': 0.14285714285714285,
#   'bated': 0.14285714285714285},
#  'the': {'castle': 0.05555555555555555,
#   'ceiling': 0.05555555555555555,
#   'size': 0.037037037037037035,
#   'slytherin': 0.037037037037037035,
#   'letter': 0.037037037037037035,
#   'place': 0.037037037037037035,
#   'quotes': 0.018518518518518517,
#   'grounds': 0.018518518518518517,
#   'nurse': 0.018518518518518517,
#   'staff': 0.018518518518518517,
#   'drinker': 0.018518518518518517,
#   'ears': 0.018518518518518517,
#   'steam': 0.018518518518518517,
#   'impression': 0.018518518518518517,
#   'lake': 0.018518518518518517,
#   'flower': 0.018518518518518517,
#   'skin': 0.018518518518518517,
#   'rain': 0.018518518518518517,
#   'speed': 0.018518518518518517,
#   'air': 0.018518518518518517,
#   'deserted': 0.018518518518518517,
#   'ghost': 0.018518518518518517,
#   'fact': 0.018518518518518517,
#   'dark': 0.018518518518518517,
#   'neck': 0.018518518518518517,
#   'headless': 0.018518518518518517,
#   'greatest': 0.018518518518518517,
#   'rest': 0.018518518518518517,
#   'skeletal': 0.018518518518518517,
#   'caretaker': 0.018518518518518517,
#   'flu': 0.018518518518518517,
#   'accusing': 0.018518518518518517,
#   'spot': 0.018518518518518517,
#   'mysterious': 0.018518518518518517,
#   'rule-breaker': 0.018518518518518517,
#   'muddy': 0.018518518518518517,
#   'number': 0.018518518518518517,
#   'floor': 0.018518518518518517,
#   'room': 0.018518518518518517,
#   'low': 0.018518518518518517,
#   'walls': 0.018518518518518517,
#   'wall': 0.018518518518518517,
#   'ink': 0.018518518518518517,
#   'end': 0.018518518518518517,
#   'office': 0.018518518518518517,
#   'oil': 0.018518518518518517},
#  'quotes': {'removed': 1.0},
#  'removed': {'october': 1.0},
#  'october': {'arrived': 1.0},
#  'arrived': {'spreadingdamp': 1.0},
#  'spreadingdamp': {'chill': 1.0},
#  'chill': {'over': 1.0},
#  'over': {'the': 1.0},
#  'grounds': {'and': 1.0},
#  'and': {'george': 0.0625,
#   'ones': 0.0625,
#   'looking': 0.0625,
#   'into': 0.03125,
#   'students': 0.03125,
#   'hagridpumpkins': 0.03125,
#   'splattered': 0.03125,
#   'wind': 0.03125,
#   'harry': 0.03125,
#   'torrential': 0.03125,
#   'tucking': 0.03125,
#   'clean': 0.03125,
#   'my': 0.03125,
#   'ridicule': 0.03125,
#   'read': 0.03125,
#   'head': 0.03125,
#   'sinew': 0.03125,
#   'beheaded': 0.03125,
#   'then': 0.03125,
#   'found': 0.03125,
#   'some': 0.03125,
#   'if': 0.03125,
#   'his': 0.03125,
#   'muck': 0.03125,
#   'followed': 0.03125,
#   'windowless': 0.03125,
#   'manacles': 0.03125,
#   'began': 0.03125,
#   'stretched': 0.03125},
#  'into': {'the': 0.5, 'taking': 0.25, 'muddy': 0.25},
#  'castle': {'.': 0.6666666666666666, 'windows': 0.3333333333333333},
#  'madam': {'pomfrey': 1.0},
#  'pomfrey': {'the': 1.0},
#  'nurse': {'was': 1.0},
#  'was': {'kept': 0.05,
#   'bullied': 0.05,
#   'on': 0.05,
#   'not': 0.05,
#   'why': 0.05,
#   'to': 0.05,
#   'no': 0.05,
#   '.': 0.05,
#   'staring': 0.05,
#   'almost': 0.05,
#   'pale': 0.05,
#   'obviously': 0.05,
#   'drowned': 0.05,
#   'mrs': 0.05,
#   'used': 0.05,
#   'unusually': 0.05,
#   'dingy': 0.05,
#   'common': 0.05,
#   'always': 0.05,
#   'onlybit': 0.05},
#  'kept': {'busy': 1.0},
#  'busy': {'bysudden': 1.0},
#  'bysudden': {'spate': 1.0},
#  'spate': {'of': 1.0},
#  'of': {'his': 0.10714285714285714,
#   'mud': 0.07142857142857142,
#   'colds': 0.03571428571428571,
#   'bullets': 0.03571428571428571,
#   'garden': 0.03571428571428571,
#   'those': 0.03571428571428571,
#   'gryffindor': 0.03571428571428571,
#   'no': 0.03571428571428571,
#   'great': 0.03571428571428571,
#   'pain': 0.03571428571428571,
#   'skin': 0.03571428571428571,
#   'harrysentence': 0.03571428571428571,
#   'lamp-like': 0.03571428571428571,
#   'deputy': 0.03571428571428571,
#   'here': 0.03571428571428571,
#   'mrs': 0.03571428571428571,
#   'ittell': 0.03571428571428571,
#   'muddy': 0.03571428571428571,
#   'fried': 0.03571428571428571,
#   'every': 0.03571428571428571,
#   'chains': 0.03571428571428571,
#   'it': 0.03571428571428571,
#   'parchment': 0.03571428571428571,
#   'him': 0.03571428571428571,
#   'the': 0.03571428571428571},
#  'colds': {'among': 1.0},
#  'among': {'the': 1.0},
#  'staff': {'and': 1.0},
#  'students': {'.': 0.5, 'avoided': 0.25, 'by': 0.25},
#  'her': {'pepperup': 0.3333333333333333,
#   'vivid': 0.3333333333333333,
#   'whole': 0.3333333333333333},
#  'pepperup': {'potion': 1.0},
#  'potion': {'worked': 1.0},
#  'worked': {'instantly': 1.0},
#  'instantly': {'though': 1.0},
#  'though': {'it': 1.0},
#  'it': {'was': 0.23076923076923078,
#   'would': 0.15384615384615385,
#   'left': 0.07692307692307693,
#   'hadnbeenhappy': 0.07692307692307693,
#   'inside': 0.07692307692307693,
#   'had': 0.07692307692307693,
#   'is': 0.07692307692307693,
#   'wasplace': 0.07692307692307693,
#   '.': 0.07692307692307693,
#   'out': 0.07692307692307693},
#  'left': {'the': 1.0},
#  'drinker': {'smoking': 1.0},
#  'smoking': {'at': 1.0},
#  'at': {'the': 0.6, 'his': 0.2, 'harry': 0.2},
#  'ears': {'for': 1.0},
#  'for': {'several': 0.1,
#   'days': 0.1,
#   'regular': 0.1,
#   'themselves': 0.1,
#   'members': 0.1,
#   'sir': 0.1,
#   'our': 0.1,
#   'the': 0.1,
#   'parchment': 0.1,
#   'his': 0.1},
#  'several': {'hours': 0.5, 'deep': 0.5},
#  'hours': {'afterward': 1.0},
#  'afterward': {'.': 1.0},
#  'ginny': {'weasley': 1.0},
#  'weasley': {'who': 0.5, 'had': 0.5},
#  'who': {'had': 0.3333333333333333,
#   'was': 0.3333333333333333,
#   'looked': 0.16666666666666666,
#   'waited': 0.16666666666666666},
#  'had': {'been': 0.18181818181818182,
#   'enough': 0.18181818181818182,
#   'seen': 0.09090909090909091,
#   'all': 0.09090909090909091,
#   'come': 0.09090909090909091,
#   'dripped': 0.09090909090909091,
#   'never': 0.09090909090909091,
#   'ever': 0.09090909090909091,
#   'an': 0.09090909090909091},
#  'been': {'looking': 0.25, 'spying': 0.25, 'quick': 0.25, 'inside': 0.25},
#  'looking': {'pale': 0.25, 'round': 0.25, 'wildly': 0.25, 'for': 0.25},
#  'pale': {'was': 0.5, 'as': 0.5},
#  'bullied': {'into': 1.0},
#  'taking': {'some': 1.0},
#  'some': {'by': 0.5, 'third': 0.5},
#  'by': {'the': 0.5, 'percy': 0.25, 'their': 0.25},
#  'percy': {'.': 1.0},
#  'steam': {'pouring': 1.0},
#  'pouring': {'from': 1.0},
#  'from': {'the': 0.4444444444444444,
#   'under': 0.1111111111111111,
#   'somewhere': 0.1111111111111111,
#   'harryquidditch': 0.1111111111111111,
#   'their': 0.1111111111111111,
#   'his': 0.1111111111111111},
#  'under': {'her': 0.5, 'his': 0.5},
#  'vivid': {'hair': 1.0},
#  'hair': {'gave': 0.5, 'andtunic': 0.5},
#  'gave': {'the': 1.0},
#  'impression': {'that': 1.0},
#  'that': {'it': 0.16666666666666666,
#   'her': 0.08333333333333333,
#   'the': 0.08333333333333333,
#   '.': 0.08333333333333333,
#   'his': 0.08333333333333333,
#   'getting': 0.08333333333333333,
#   'you': 0.08333333333333333,
#   'seemed': 0.08333333333333333,
#   'had': 0.08333333333333333,
#   'they': 0.08333333333333333,
#   'he': 0.08333333333333333},
#  'whole': {'head': 1.0},
#  'head': {'was': 0.25, 'had': 0.25, 'polo': 0.25, 'and': 0.25},
#  'on': {'the': 0.45454545454545453,
#   'his': 0.2727272727272727,
#   'fire': 0.09090909090909091,
#   'end': 0.09090909090909091,
#   'harry': 0.09090909090909091},
#  'fire': {'.': 1.0},
#  'raindrops': {'the': 1.0},
#  'size': {'of': 1.0},
#  'bullets': {'thundered': 1.0},
#  'thundered': {'on': 1.0},
#  'windows': {'for': 1.0},
#  'days': {'on': 0.5, 'before': 0.5},
#  'end': {'the': 0.5, 'of': 0.5},
#  'lake': {'rose': 1.0},
#  'rose': {'the': 1.0},
#  'flower': {'beds': 1.0},
#  'beds': {'turned': 1.0},
#  'turned': {'into': 1.0},
#  'muddy': {'streams': 0.3333333333333333,
#   'puddle': 0.3333333333333333,
#   'footprints': 0.3333333333333333},
#  'streams': {'and': 1.0},
#  'hagridpumpkins': {'swelled': 1.0},
#  'swelled': {'to': 1.0},
#  'to': {'the': 0.2222222222222222,
#   'join': 0.1111111111111111,
#   'be': 0.05555555555555555,
#   'gryffindor': 0.05555555555555555,
#   'agree': 0.05555555555555555,
#   'participate': 0.05555555555555555,
#   'connect': 0.05555555555555555,
#   'harryright': 0.05555555555555555,
#   'nearly': 0.05555555555555555,
#   'themselves': 0.05555555555555555,
#   'let': 0.05555555555555555,
#   'you': 0.05555555555555555,
#   'me': 0.05555555555555555,
#   'fall': 0.05555555555555555},
#  'garden': {'sheds': 1.0},
#  'sheds': {'.': 1.0},
#  'oliver': {'woodenthusiasm': 1.0},
#  'woodenthusiasm': {'for': 1.0},
#  'regular': {'training': 1.0},
#  'training': {'sessions': 1.0},
#  'sessions': {'however': 1.0},
#  'however': {'was': 0.5, '-': 0.5},
#  'not': {'dampened': 0.25, 'fulfill': 0.25, 'unless': 0.25, 'quickly': 0.25},
#  'dampened': {'which': 1.0},
#  'which': {'was': 0.3333333333333333,
#   'concealed': 0.3333333333333333,
#   'made': 0.3333333333333333},
#  'why': {'harry': 1.0},
#  'harry': {'.': 0.25,
#   'could': 0.125,
#   'who': 0.125,
#   'was': 0.0625,
#   'squelched': 0.0625,
#   'most': 0.0625,
#   'said': 0.0625,
#   'backing': 0.0625,
#   'wavedgloomy': 0.0625,
#   'had': 0.0625,
#   'potter': 0.0625},
#  'be': {'found': 0.5, 'impossible': 0.5},
#  'found': {'late': 0.5, 'himself': 0.5},
#  'late': {'one': 1.0},
#  'one': {'stormy': 1.0},
#  'stormy': {'saturday': 1.0},
#  'saturday': {'afternoonfew': 1.0},
#  'afternoonfew': {'days': 1.0},
#  'before': {'halloween': 0.5, 'it': 0.5},
#  'halloween': {'returning': 1.0},
#  'returning': {'to': 1.0},
#  'gryffindor': {'tower': 1.0},
#  'tower': {'drenched': 0.5, 'was': 0.5},
#  'drenched': {'to': 1.0},
#  'skin': {'and': 1.0},
#  'splattered': {'with': 1.0},
#  'mud': {'.': 0.25, 'all': 0.25, 'said': 0.25, 'to': 0.25},
#  'even': {'aside': 1.0},
#  'aside': {'from': 1.0},
#  'rain': {'and': 0.5, 'outside': 0.5},
#  'wind': {'it': 1.0},
#  'hadnbeenhappy': {'practice': 1.0},
#  'practice': {'session': 1.0},
#  'session': {'.': 1.0},
#  'fred': {'and': 1.0},
#  'george': {'who': 0.5, 'weasley': 0.5},
#  'spying': {'on': 1.0},
#  'slytherin': {'team': 1.0},
#  'team': {'had': 0.5, 'was': 0.5},
#  'seen': {'for': 1.0},
#  'themselves': {'the': 0.5, '.highly': 0.5},
#  'speed': {'of': 1.0},
#  'those': {'new': 1.0},
#  'new': {'nimbus': 1.0},
#  'nimbus': {'two': 1.0},
#  'two': {'thousand': 1.0},
#  'thousand': {'and': 1.0},
#  'ones': {'.': 0.5, 'for': 0.5},
#  'they': {'reported': 0.5, 'contained': 0.5},
#  'reported': {'that': 1.0},
#  'no': {'more': 0.25, 'importance': 0.25, 'itnot': 0.25, 'said': 0.25},
#  'more': {'than': 0.5, 'thando': 0.5},
#  'than': {'seven': 1.0},
#  'seven': {'greenish': 0.5, 'free': 0.5},
#  'greenish': {'blurs': 1.0},
#  'blurs': {'shooting': 1.0},
#  'shooting': {'through': 1.0},
#  'through': {'the': 0.5, 'him': 0.5},
#  'air': {'like': 1.0},
#  'like': {'missiles': 1.0},
#  'missiles': {'.': 1.0},
#  'as': {'he': 0.3333333333333333,
#   'harry': 0.1111111111111111,
#   'preoccupied': 0.1111111111111111,
#   'smoke': 0.1111111111111111,
#   'thoughreally': 0.1111111111111111,
#   'horseback': 0.1111111111111111,
#   'filch': 0.1111111111111111},
#  'squelched': {'along': 1.0},
#  'along': {'the': 1.0},
#  'deserted': {'corridor': 1.0},
#  'corridor': {'he': 1.0},
#  'he': {'was': 0.23076923076923078,
#   'came': 0.07692307692307693,
#   'woredashing': 0.07692307692307693,
#   'spoke': 0.07692307692307693,
#   'erupted': 0.07692307692307693,
#   'looked': 0.07692307692307693,
#   'sees': 0.07692307692307693,
#   'shouted': 0.07692307692307693,
#   'pointed': 0.07692307692307693,
#   'muttered': 0.07692307692307693,
#   'retrievedlarge': 0.07692307692307693},
#  'came': {'across': 1.0},
#  'across': {'somebody': 1.0},
#  'somebody': {'who': 1.0},
#  'looked': {'just': 0.5, 'down': 0.5},
#  'just': {'as': 1.0},
#  'preoccupied': {'as': 1.0},
#  'nearly': {'headless': 1.0},
#  'headless': {'nick': 0.875, 'hunt': 0.125},
#  'nick': {'the': 0.1,
#   'said': 0.1,
#   'starting': 0.1,
#   'foldingtransparent': 0.1,
#   'waved': 0.1,
#   'shook': 0.1,
#   'stuffed': 0.1,
#   'took': 0.1,
#   'quickly': 0.1,
#   'and': 0.1},
#  'ghost': {'of': 1.0},
#  'staring': {'morosely': 1.0},
#  'morosely': {'out': 1.0},
#  'out': {'of': 0.4, 'ofwindow': 0.2, 'byhigh-pitched': 0.2, 'in': 0.2},
#  'ofwindow': {'muttering': 1.0},
#  'muttering': {'under': 1.0},
#  'his': {'long': 0.09090909090909091,
#   'desk': 0.09090909090909091,
#   'breath': 0.045454545454545456,
#   'neck': 0.045454545454545456,
#   'doublet': 0.045454545454545456,
#   'airy': 0.045454545454545456,
#   'face': 0.045454545454545456,
#   'pocket': 0.045454545454545456,
#   'letter': 0.045454545454545456,
#   'ankles': 0.045454545454545456,
#   'endless': 0.045454545454545456,
#   'foul': 0.045454545454545456,
#   'head': 0.045454545454545456,
#   'nose': 0.045454545454545456,
#   'jowls': 0.045454545454545456,
#   'eyes': 0.045454545454545456,
#   'bulbous': 0.045454545454545456,
#   'streaming': 0.045454545454545456,
#   'sentence': 0.045454545454545456,
#   'quill': 0.045454545454545456},
#  'breath': {'.': 0.5, 'for': 0.5},
#  'donfulfill': {'their': 1.0},
#  'their': {'requirements': 0.25,
#   'bodies': 0.25,
#   'labels': 0.25,
#   'ankles': 0.25},
#  'requirements': {'.': 0.6666666666666666, '-': 0.3333333333333333},
#  'half': {'an': 1.0},
#  'an': {'inch': 0.4, 'elegant': 0.2, 'entire': 0.2, 'example': 0.2},
#  'inch': {'if': 0.5, 'of': 0.5},
#  'if': {'that': 0.5, 'he': 0.5},
#  'hello': {'nick': 0.3333333333333333,
#   'hello': 0.3333333333333333,
#   'said': 0.3333333333333333},
#  'said': {'harry': 0.6, 'nick': 0.2, 'nearly': 0.1, 'infar': 0.1},
#  'starting': {'and': 1.0},
#  'round': {'.': 1.0},
#  'woredashing': {'plumed': 1.0},
#  'plumed': {'hat': 1.0},
#  'hat': {'on': 1.0},
#  'long': {'curly': 0.5, 'black': 0.5},
#  'curly': {'hair': 1.0},
#  'andtunic': {'withruff': 1.0},
#  'withruff': {'which': 1.0},
#  'concealed': {'the': 1.0},
#  'fact': {'that': 1.0},
#  'neck': {'was': 0.3333333333333333,
#   'withblunt': 0.3333333333333333,
#   'on': 0.3333333333333333},
#  'almost': {'completely': 1.0},
#  'completely': {'severed': 1.0},
#  'severed': {'.': 1.0},
#  'smoke': {'and': 1.0},
#  'could': {'see': 1.0},
#  'see': {'right': 0.5, 'that': 0.5},
#  'right': {'through': 0.5, 'said': 0.5},
#  'him': {'to': 0.25, 'with': 0.25, 'suspend': 0.25, 'dipping': 0.25},
#  'dark': {'sky': 1.0},
#  'sky': {'and': 1.0},
#  'torrential': {'rain': 1.0},
#  'outside': {'.': 1.0},
#  'you': {'look': 0.08333333333333333,
#   'said': 0.08333333333333333,
#   'would': 0.08333333333333333,
#   'to': 0.08333333333333333,
#   'will': 0.08333333333333333,
#   'that': 0.08333333333333333,
#   'do': 0.08333333333333333,
#   'anythingcan': 0.08333333333333333,
#   'know': 0.08333333333333333,
#   'dripping': 0.08333333333333333,
#   'follow': 0.08333333333333333,
#   'boy': 0.08333333333333333},
#  'look': {'troubled': 1.0},
#  'troubled': {'young': 1.0},
#  'young': {'potter': 1.0},
#  'potter': {'said': 0.3333333333333333,
#   'so': 0.3333333333333333,
#   '.': 0.3333333333333333},
#  'foldingtransparent': {'letter': 1.0},
#  'letter': {'as': 0.25, 'back': 0.25, 'open': 0.25, 'away': 0.25},
#  'spoke': {'and': 1.0},
#  'tucking': {'it': 1.0},
#  'inside': {'his': 0.5, 'filchoffice': 0.5},
#  'doublet': {'.': 1.0},
#  'so': {'do': 0.3333333333333333,
#   '-': 0.3333333333333333,
#   'harry': 0.3333333333333333},
#  'do': {'you': 0.3333333333333333,
#   'not': 0.3333333333333333,
#   'no': 0.3333333333333333},
#  'ah': {'nearly': 1.0},
#  'waved': {'an': 1.0},
#  'elegant': {'handmatter': 1.0},
#  'handmatter': {'of': 1.0},
#  'importance': {'.': 1.0},
#  'itnot': {'as': 0.5, 'enough': 0.5},
#  'thoughreally': {'wanted': 1.0},
#  'wanted': {'to': 1.0},
#  'join': {'.': 0.5, 'the': 0.5},
#  'thoughtd': {'apply': 1.0},
#  'apply': {'but': 1.0},
#  'but': {'apparentlydonfulfill': 0.16666666666666666,
#   'you': 0.16666666666666666,
#   'oh': 0.16666666666666666,
#   'not': 0.16666666666666666,
#   'to': 0.16666666666666666,
#   'as': 0.16666666666666666},
#  'apparentlydonfulfill': {'requirements': 1.0},
#  '-': {'in': 0.14285714285714285,
#   'yes': 0.14285714285714285,
#   'nearly': 0.14285714285714285,
#   'whatbothering': 0.14285714285714285,
#   'the': 0.14285714285714285,
#   'hegot': 0.14285714285714285,
#   'right': 0.14285714285714285},
#  'in': {'spite': 0.16666666666666666,
#   'the': 0.16666666666666666,
#   'hunt': 0.16666666666666666,
#   'his': 0.16666666666666666,
#   'dungeon': 0.16666666666666666,
#   'front': 0.16666666666666666},
#  'spite': {'of': 1.0},
#  'airy': {'tone': 1.0},
#  'tone': {'there': 0.5, 'so': 0.5},
#  'there': {'waslook': 0.3333333333333333,
#   'wasthick': 0.3333333333333333,
#   'wasgreat': 0.3333333333333333},
#  'waslook': {'of': 1.0},
#  'great': {'bitterness': 0.5, 'sizzling': 0.5},
#  'bitterness': {'on': 1.0},
#  'face': {'.': 1.0},
#  'would': {'think': 0.4, 'qualify': 0.2, 'have': 0.2, 'be': 0.2},
#  'think': {'wouldnyou': 0.5, 'thatgood': 0.5},
#  'wouldnyou': {'he': 1.0},
#  'erupted': {'suddenly': 1.0},
#  'suddenly': {'pulling': 0.5, 'throughtapestry': 0.5},
#  'pulling': {'the': 1.0},
#  'back': {'out': 0.5, 'downstairs': 0.5},
#  'pocket': {'that': 1.0},
#  'getting': {'hit': 1.0},
#  'hit': {'forty-five': 1.0},
#  'forty-five': {'times': 1.0},
#  'times': {'in': 1.0},
#  'withblunt': {'axe': 1.0},
#  'axe': {'would': 1.0},
#  'qualify': {'you': 1.0},
#  'hunt': {'oh': 0.5, 'activities': 0.5},
#  'oh': {'-': 0.5, 'no': 0.5},
#  'yes': {'said': 0.5, '.': 0.5},
#  'obviously': {'supposed': 1.0},
#  'supposed': {'to': 1.0},
#  'agree': {'.mean': 1.0},
#  '.mean': {'nobody': 1.0},
#  'nobody': {'wishes': 1.0},
#  'wishes': {'more': 0.5, 'sir': 0.5},
#  'thando': {'that': 1.0},
#  'all': {'over': 0.5, 'been': 0.25, 'morning': 0.25},
#  'quick': {'and': 1.0},
#  'clean': {'and': 1.0},
#  'my': {'head': 0.5, 'neck': 0.5},
#  'come': {'off': 1.0},
#  'off': {'properlymean': 1.0},
#  'properlymean': {'it': 1.0},
#  'have': {'saved': 0.5, 'parted': 0.5},
#  'saved': {'megreat': 1.0},
#  'megreat': {'deal': 1.0},
#  'deal': {'of': 1.0},
#  'pain': {'and': 1.0},
#  'ridicule': {'.': 1.0},
#  'shook': {'his': 1.0},
#  'open': {'and': 1.0},
#  'read': {'furiously': 1.0},
#  'furiously': {'we': 0.5, 'great': 0.5},
#  'we': {'can': 1.0},
#  'can': {'only': 0.5, 'get': 0.5},
#  'only': {'accept': 1.0},
#  'accept': {'huntsmen': 1.0},
#  'huntsmen': {'whose': 1.0},
#  'whose': {'heads': 1.0},
#  'heads': {'have': 1.0},
#  'parted': {'company': 1.0},
#  'company': {'with': 1.0},
#  'bodies': {'.': 1.0},
#  'will': {'appreciate': 1.0},
#  'appreciate': {'that': 1.0},
#  'impossible': {'otherwise': 1.0},
#  'otherwise': {'for': 1.0},
#  'members': {'to': 1.0},
#  'participate': {'in': 1.0},
#  'activities': {'such': 1.0},
#  'such': {'as': 1.0},
#  'horseback': {'head-juggling': 1.0},
#  'head-juggling': {'and': 1.0},
#  'polo': {'.': 1.0},
#  'is': {'with': 1.0},
#  'greatest': {'regret': 1.0},
#  'regret': {'therefore': 1.0},
#  'therefore': {'thatmust': 1.0},
#  'thatmust': {'inform': 1.0},
#  'inform': {'you': 1.0},
#  'fulfill': {'our': 1.0},
#  'our': {'requirements': 0.5, 'match': 0.5},
#  'very': {'best': 1.0},
#  'best': {'wishes': 1.0},
#  'sir': {'patrick': 0.5, 'properly': 0.5},
#  'patrick': {'delaney-podmore': 1.0},
#  'delaney-podmore': {'.': 1.0},
#  'fuming': {'nearly': 1.0},
#  'stuffed': {'the': 1.0},
#  'away': {'.': 0.5, 'from': 0.5},
#  'sinew': {'holding': 1.0},
#  'holding': {'my': 1.0},
#  'most': {'people': 0.5, 'students': 0.5},
#  'people': {'would': 1.0},
#  'thatgood': {'and': 1.0},
#  'beheaded': {'but': 1.0},
#  'enough': {'of': 0.5, 'for': 0.25, '.': 0.25},
#  'properly': {'decapitated-podmore': 1.0},
#  'decapitated-podmore': {'.': 1.0},
#  'took': {'several': 1.0},
#  'deep': {'breaths': 1.0},
#  'breaths': {'and': 1.0},
#  'then': {'said': 1.0},
#  'infar': {'calmer': 1.0},
#  'calmer': {'tone': 1.0},
#  'whatbothering': {'you': 1.0},
#  'anythingcan': {'do': 1.0},
#  'unless': {'you': 1.0},
#  'know': {'where': 1.0},
#  'where': {'we': 1.0},
#  'get': {'seven': 0.5, 'out': 0.5},
#  'free': {'nimbus': 1.0},
#  'match': {'against': 1.0},
#  'against': {'sly': 0.5, 'students': 0.5},
#  'sly': {'-': 1.0},
#  'rest': {'of': 1.0},
#  'harrysentence': {'was': 1.0},
#  'drowned': {'out': 1.0},
#  'byhigh-pitched': {'mewling': 1.0},
#  'mewling': {'from': 1.0},
#  'somewhere': {'near': 1.0},
#  'near': {'his': 1.0},
#  'ankles': {'.': 0.5, 'from': 0.5},
#  'down': {'and': 1.0},
#  'himself': {'gazing': 1.0},
#  'gazing': {'intopair': 1.0},
#  'intopair': {'of': 1.0},
#  'lamp-like': {'yellow': 1.0},
#  'yellow': {'eyes': 1.0},
#  'eyes': {'.': 0.5, 'popping': 0.5},
#  'mrs': {'.': 1.0},
#  'norris': {'the': 0.5, 'but': 0.5},
#  'skeletal': {'gray': 1.0},
#  'gray': {'cat': 1.0},
#  'cat': {'who': 0.5, 'argus': 0.5},
#  'used': {'by': 1.0},
#  'caretaker': {'argus': 1.0},
#  'argus': {'filch': 1.0},
#  'filch': {'assort': 0.125,
#   'isningood': 0.125,
#   'burst': 0.125,
#   'back': 0.125,
#   'had': 0.125,
#   'grabbedquill': 0.125,
#   'squinted': 0.125,
#   'lowered': 0.125},
#  'assort': {'of': 1.0},
#  'deputy': {'in': 1.0},
#  'endless': {'battle': 1.0},
#  'battle': {'against': 1.0},
#  'youbetter': {'get': 1.0},
#  'here': {'harry': 1.0},
#  'quickly': {'.': 0.5, 'enough': 0.5},
#  'isningood': {'mood': 1.0},
#  'mood': {'-': 1.0},
#  'hegot': {'the': 1.0},
#  'flu': {'and': 1.0},
#  'third': {'years': 1.0},
#  'years': {'accidentally': 1.0},
#  'accidentally': {'plastered': 1.0},
#  'plastered': {'frog': 1.0},
#  'frog': {'brains': 1.0},
#  'brains': {'all': 0.5, '.': 0.5},
#  'ceiling': {'in': 0.25, '.faint': 0.25, '.': 0.25, 'of': 0.25},
#  'dungeon': {'five': 1.0},
#  'five': {'.': 1.0},
#  'hebeen': {'cleaning': 1.0},
#  'cleaning': {'all': 1.0},
#  'morning': {'and': 1.0},
#  'sees': {'you': 1.0},
#  'dripping': {'mud': 1.0},
#  'place': {'-': 0.5, '.': 0.5},
#  'backing': {'away': 1.0},
#  'accusing': {'stare': 1.0},
#  'stare': {'of': 1.0},
#  'drawn': {'to': 1.0},
#  'spot': {'by': 1.0},
#  'mysterious': {'power': 1.0},
#  'power': {'that': 1.0},
#  'seemed': {'to': 1.0},
#  'connect': {'him': 1.0},
#  'foul': {'cat': 1.0},
#  'burst': {'suddenly': 1.0},
#  'throughtapestry': {'to': 1.0},
#  'harryright': {'wheezing': 1.0},
#  'wheezing': {'and': 1.0},
#  'wildly': {'about': 1.0},
#  'about': {'for': 0.5, 'the': 0.5},
#  'rule-breaker': {'.': 1.0},
#  'wasthick': {'tartan': 1.0},
#  'tartan': {'scarf': 1.0},
#  'scarf': {'bound': 1.0},
#  'bound': {'around': 1.0},
#  'around': {'his': 0.3333333333333333,
#   'the': 0.3333333333333333,
#   'looking': 0.3333333333333333},
#  'nose': {'was': 0.3333333333333333,
#   '.': 0.3333333333333333,
#   'filch': 0.3333333333333333},
#  'unusually': {'purple': 1.0},
#  'purple': {'.': 1.0},
#  'filth': {'he': 1.0},
#  'shouted': {'his': 0.5, 'filchdrip': 0.5},
#  'jowls': {'aquiver': 1.0},
#  'aquiver': {'his': 1.0},
#  'popping': {'alarmingly': 1.0},
#  'alarmingly': {'as': 1.0},
#  'pointed': {'at': 1.0},
#  'puddle': {'that': 1.0},
#  'dripped': {'from': 1.0},
#  'harryquidditch': {'robes': 1.0},
#  'robes': {'.': 1.0},
#  'mess': {'and': 1.0},
#  'muck': {'everywhereve': 1.0},
#  'everywhereve': {'had': 1.0},
#  'ittell': {'you': 1.0},
#  'follow': {'me': 1.0},
#  'me': {'potter': 0.5, 'itan': 0.5},
#  'wavedgloomy': {'good-bye': 1.0},
#  'good-bye': {'to': 1.0},
#  'followed': {'filch': 1.0},
#  'downstairs': {'doubling': 1.0},
#  'doubling': {'the': 1.0},
#  'number': {'of': 1.0},
#  'footprints': {'on': 1.0},
#  'floor': {'.': 1.0},
#  'never': {'been': 1.0},
#  'filchoffice': {'before': 1.0},
#  'wasplace': {'most': 1.0},
#  'avoided': {'.': 1.0},
#  'room': {'was': 1.0},
#  'dingy': {'and': 1.0},
#  'windowless': {'lit': 1.0},
#  'lit': {'bysingle': 1.0},
#  'bysingle': {'oil': 1.0},
#  'oil': {'lamp': 1.0},
#  'lamp': {'dangling': 1.0},
#  'dangling': {'from': 1.0},
#  'low': {'ceiling': 1.0},
#  '.faint': {'smell': 1.0},
#  'smell': {'of': 1.0},
#  'fried': {'fish': 1.0},
#  'fish': {'lingered': 1.0},
#  'lingered': {'about': 1.0},
#  'wooden': {'filing': 1.0},
#  'filing': {'cabinets': 1.0},
#  'cabinets': {'stood': 1.0},
#  'stood': {'around': 1.0},
#  'walls': {'from': 1.0},
#  'labels': {'harry': 1.0},
#  'contained': {'details': 1.0},
#  'details': {'of': 1.0},
#  'every': {'pupil': 1.0},
#  'pupil': {'filch': 1.0},
#  'ever': {'punished': 1.0},
#  'punished': {'.': 1.0},
#  'entire': {'drawer': 1.0},
#  'drawer': {'to': 0.5, 'and': 0.5},
#  '.highly': {'polished': 1.0},
#  'polished': {'collection': 1.0},
#  'collection': {'of': 1.0},
#  'chains': {'and': 1.0},
#  'manacles': {'hung': 1.0},
#  'hung': {'on': 1.0},
#  'wall': {'behind': 1.0},
#  'behind': {'filchdesk': 1.0},
#  'filchdesk': {'.': 1.0},
#  'common': {'knowledge': 1.0},
#  'knowledge': {'that': 1.0},
#  'always': {'begging': 1.0},
#  'begging': {'dumbledore': 1.0},
#  'dumbledore': {'to': 1.0},
#  'let': {'him': 1.0},
#  'suspend': {'students': 1.0},
#  'grabbedquill': {'frompot': 1.0},
#  'frompot': {'on': 1.0},
#  'desk': {'and': 0.5, 'drawer': 0.5},
#  'began': {'shuffling': 1.0},
#  'shuffling': {'around': 1.0},
#  'parchment': {'.': 0.5, 'from': 0.5},
#  'dung': {'he': 1.0},
#  'muttered': {'furiously': 1.0},
#  'sizzling': {'dragon': 1.0},
#  'dragon': {'bogies': 1.0},
#  'bogies': {'.': 1.0},
#  'rat': {'intestines': 1.0},
#  'intestines': {'.': 1.0},
#  '.ve': {'had': 1.0},
#  'make': {'an': 1.0},
#  'example': {'.': 1.0},
#  'wherethe': {'form': 1.0},
#  'form': {'.': 1.0},
#  'retrievedlarge': {'roll': 1.0},
#  'roll': {'of': 1.0},
#  'stretched': {'it': 1.0},
#  'front': {'of': 1.0},
#  'dipping': {'his': 1.0},
#  'black': {'quill': 1.0},
#  'quill': {'into': 0.5, 'there': 0.5},
#  'ink': {'pot': 1.0},
#  'pot': {'.': 1.0},
#  'name': {'.': 1.0},
#  'crime': {'.': 1.0},
#  'onlybit': {'of': 1.0},
#  'itonlybit': {'of': 1.0},
#  'boy': {'but': 1.0},
#  'itan': {'extra': 1.0},
#  'extra': {'hour': 1.0},
#  'hour': {'scrubbing': 1.0},
#  'scrubbing': {'shouted': 1.0},
#  'filchdrip': {'shivering': 1.0},
#  'shivering': {'unpleasantly': 1.0},
#  'unpleasantly': {'at': 1.0},
#  'bulbous': {'nose': 1.0},
#  'befouling': {'the': 1.0},
#  'suggested': {'sentence': 1.0},
#  'sentence': {'.': 0.5, 'to': 0.5},
#  'dabbing': {'at': 1.0},
#  'streaming': {'nose': 1.0},
#  'squinted': {'unpleasantly': 1.0},
#  'waited': {'with': 1.0},
#  'bated': {'breath': 1.0},
#  'fall': {'.': 1.0},
#  'lowered': {'his': 1.0},
#  'wasgreat': {'bang': 1.0},
#  'bang': {'on': 1.0},
#  'office': {'which': 1.0},
#  'made': {'the': 1.0}}

# %%
trigrammes
# Out:
# {('.', 'herethe'): {'text': 1.0},
#  ('herethe', 'text'): {'with': 1.0},
#  ('text', 'with'): {'the': 1.0},
#  ('with', 'the'): {'quotes': 0.5, 'greatest': 0.5},
#  ('the', 'quotes'): {'removed': 1.0},
#  ('quotes', 'removed'): {'october': 1.0},
#  ('removed', 'october'): {'arrived': 1.0},
#  ('october', 'arrived'): {'spreadingdamp': 1.0},
#  ('arrived', 'spreadingdamp'): {'chill': 1.0},
#  ('spreadingdamp', 'chill'): {'over': 1.0},
#  ('chill', 'over'): {'the': 1.0},
#  ('over', 'the'): {'grounds': 0.3333333333333333,
#   'ceiling': 0.3333333333333333,
#   'place': 0.3333333333333333},
#  ('the', 'grounds'): {'and': 1.0},
#  ('grounds', 'and'): {'into': 1.0},
#  ('and', 'into'): {'the': 1.0},
#  ('into', 'the'): {'castle': 0.5, 'ink': 0.5},
#  ('the', 'castle'): {'.': 0.6666666666666666, 'windows': 0.3333333333333333},
#  ('castle', '.'): {'madam': 0.5, '.': 0.5},
#  ('.', 'madam'): {'pomfrey': 1.0},
#  ('madam', 'pomfrey'): {'the': 1.0},
#  ('pomfrey', 'the'): {'nurse': 1.0},
#  ('the', 'nurse'): {'was': 1.0},
#  ('nurse', 'was'): {'kept': 1.0},
#  ('was', 'kept'): {'busy': 1.0},
#  ('kept', 'busy'): {'bysudden': 1.0},
#  ('busy', 'bysudden'): {'spate': 1.0},
#  ('bysudden', 'spate'): {'of': 1.0},
#  ('spate', 'of'): {'colds': 1.0},
#  ('of', 'colds'): {'among': 1.0},
#  ('colds', 'among'): {'the': 1.0},
#  ('among', 'the'): {'staff': 1.0},
#  ('the', 'staff'): {'and': 1.0},
#  ('staff', 'and'): {'students': 1.0},
#  ('and', 'students'): {'.': 1.0},
#  ('students', '.'): {'her': 0.5, 'youbetter': 0.5},
#  ('.', 'her'): {'pepperup': 1.0},
#  ('her', 'pepperup'): {'potion': 1.0},
#  ('pepperup', 'potion'): {'worked': 1.0},
#  ('potion', 'worked'): {'instantly': 1.0},
#  ('worked', 'instantly'): {'though': 1.0},
#  ('instantly', 'though'): {'it': 1.0},
#  ('though', 'it'): {'left': 1.0},
#  ('it', 'left'): {'the': 1.0},
#  ('left', 'the'): {'drinker': 1.0},
#  ('the', 'drinker'): {'smoking': 1.0},
#  ('drinker', 'smoking'): {'at': 1.0},
#  ('smoking', 'at'): {'the': 1.0},
#  ('at', 'the'): {'ears': 0.3333333333333333,
#   'muddy': 0.3333333333333333,
#   'end': 0.3333333333333333},
#  ('the', 'ears'): {'for': 1.0},
#  ('ears', 'for'): {'several': 1.0},
#  ('for', 'several'): {'hours': 1.0},
#  ('several', 'hours'): {'afterward': 1.0},
#  ('hours', 'afterward'): {'.': 1.0},
#  ('afterward', '.'): {'ginny': 1.0},
#  ('.', 'ginny'): {'weasley': 1.0},
#  ('ginny', 'weasley'): {'who': 1.0},
#  ('weasley', 'who'): {'had': 1.0},
#  ('who', 'had'): {'been': 1.0},
#  ('had', 'been'): {'looking': 0.5, 'spying': 0.5},
#  ('been', 'looking'): {'pale': 1.0},
#  ('looking', 'pale'): {'was': 1.0},
#  ('pale', 'was'): {'bullied': 1.0},
#  ('was', 'bullied'): {'into': 1.0},
#  ('bullied', 'into'): {'taking': 1.0},
#  ('into', 'taking'): {'some': 1.0},
#  ('taking', 'some'): {'by': 1.0},
#  ('some', 'by'): {'percy': 1.0},
#  ('by', 'percy'): {'.': 1.0},
#  ('percy', '.'): {'the': 1.0},
#  ('.', 'the'): {'steam': 0.5, 'room': 0.5},
#  ('the', 'steam'): {'pouring': 1.0},
#  ('steam', 'pouring'): {'from': 1.0},
#  ('pouring', 'from'): {'under': 1.0},
#  ('from', 'under'): {'her': 1.0},
#  ('under', 'her'): {'vivid': 1.0},
#  ('her', 'vivid'): {'hair': 1.0},
#  ('vivid', 'hair'): {'gave': 1.0},
#  ('hair', 'gave'): {'the': 1.0},
#  ('gave', 'the'): {'impression': 1.0},
#  ('the', 'impression'): {'that': 1.0},
#  ('impression', 'that'): {'her': 1.0},
#  ('that', 'her'): {'whole': 1.0},
#  ('her', 'whole'): {'head': 1.0},
#  ('whole', 'head'): {'was': 1.0},
#  ('head', 'was'): {'on': 1.0},
#  ('was', 'on'): {'fire': 1.0},
#  ('on', 'fire'): {'.': 1.0},
#  ('fire', '.'): {'raindrops': 1.0},
#  ('.', 'raindrops'): {'the': 1.0},
#  ('raindrops', 'the'): {'size': 1.0},
#  ('the', 'size'): {'of': 1.0},
#  ('size', 'of'): {'bullets': 0.5, 'garden': 0.5},
#  ('of', 'bullets'): {'thundered': 1.0},
#  ('bullets', 'thundered'): {'on': 1.0},
#  ('thundered', 'on'): {'the': 1.0},
#  ('on', 'the'): {'castle': 0.2,
#   'slytherin': 0.2,
#   'floor': 0.2,
#   'wall': 0.2,
#   'ceiling': 0.2},
#  ('castle', 'windows'): {'for': 1.0},
#  ('windows', 'for'): {'days': 1.0},
#  ('for', 'days'): {'on': 1.0},
#  ('days', 'on'): {'end': 1.0},
#  ('on', 'end'): {'the': 1.0},
#  ('end', 'the'): {'lake': 1.0},
#  ('the', 'lake'): {'rose': 1.0},
#  ('lake', 'rose'): {'the': 1.0},
#  ('rose', 'the'): {'flower': 1.0},
#  ('the', 'flower'): {'beds': 1.0},
#  ('flower', 'beds'): {'turned': 1.0},
#  ('beds', 'turned'): {'into': 1.0},
#  ('turned', 'into'): {'muddy': 1.0},
#  ('into', 'muddy'): {'streams': 1.0},
#  ('muddy', 'streams'): {'and': 1.0},
#  ('streams', 'and'): {'hagridpumpkins': 1.0},
#  ('and', 'hagridpumpkins'): {'swelled': 1.0},
#  ('hagridpumpkins', 'swelled'): {'to': 1.0},
#  ('swelled', 'to'): {'the': 1.0},
#  ('to', 'the'): {'size': 0.25, 'skin': 0.25, 'dark': 0.25, 'spot': 0.25},
#  ('of', 'garden'): {'sheds': 1.0},
#  ('garden', 'sheds'): {'.': 1.0},
#  ('sheds', '.'): {'oliver': 1.0},
#  ('.', 'oliver'): {'woodenthusiasm': 1.0},
#  ('oliver', 'woodenthusiasm'): {'for': 1.0},
#  ('woodenthusiasm', 'for'): {'regular': 1.0},
#  ('for', 'regular'): {'training': 1.0},
#  ('regular', 'training'): {'sessions': 1.0},
#  ('training', 'sessions'): {'however': 1.0},
#  ('sessions', 'however'): {'was': 1.0},
#  ('however', 'was'): {'not': 1.0},
#  ('was', 'not'): {'dampened': 1.0},
#  ('not', 'dampened'): {'which': 1.0},
#  ('dampened', 'which'): {'was': 1.0},
#  ('which', 'was'): {'why': 1.0},
#  ('was', 'why'): {'harry': 1.0},
#  ('why', 'harry'): {'was': 1.0},
#  ('harry', 'was'): {'to': 1.0},
#  ('was', 'to'): {'be': 1.0},
#  ('to', 'be'): {'found': 1.0},
#  ('be', 'found'): {'late': 1.0},
#  ('found', 'late'): {'one': 1.0},
#  ('late', 'one'): {'stormy': 1.0},
#  ('one', 'stormy'): {'saturday': 1.0},
#  ('stormy', 'saturday'): {'afternoonfew': 1.0},
#  ('saturday', 'afternoonfew'): {'days': 1.0},
#  ('afternoonfew', 'days'): {'before': 1.0},
#  ('days', 'before'): {'halloween': 1.0},
#  ('before', 'halloween'): {'returning': 1.0},
#  ('halloween', 'returning'): {'to': 1.0},
#  ('returning', 'to'): {'gryffindor': 1.0},
#  ('to', 'gryffindor'): {'tower': 1.0},
#  ('gryffindor', 'tower'): {'drenched': 0.5, 'was': 0.5},
#  ('tower', 'drenched'): {'to': 1.0},
#  ('drenched', 'to'): {'the': 1.0},
#  ('the', 'skin'): {'and': 1.0},
#  ('skin', 'and'): {'splattered': 0.5, 'sinew': 0.5},
#  ('and', 'splattered'): {'with': 1.0},
#  ('splattered', 'with'): {'mud': 1.0},
#  ('with', 'mud'): {'.': 1.0},
#  ('mud', '.'): {'even': 1.0},
#  ('.', 'even'): {'aside': 1.0},
#  ('even', 'aside'): {'from': 1.0},
#  ('aside', 'from'): {'the': 1.0},
#  ('from', 'the'): {'rain': 0.25,
#   'accusing': 0.25,
#   'low': 0.25,
#   'ceiling': 0.25},
#  ('the', 'rain'): {'and': 1.0},
#  ('rain', 'and'): {'wind': 1.0},
#  ('and', 'wind'): {'it': 1.0},
#  ('wind', 'it'): {'hadnbeenhappy': 1.0},
#  ('it', 'hadnbeenhappy'): {'practice': 1.0},
#  ('hadnbeenhappy', 'practice'): {'session': 1.0},
#  ('practice', 'session'): {'.': 1.0},
#  ('session', '.'): {'fred': 1.0},
#  ('.', 'fred'): {'and': 1.0},
#  ('fred', 'and'): {'george': 1.0},
#  ('and', 'george'): {'who': 0.5, 'weasley': 0.5},
#  ('george', 'who'): {'had': 1.0},
#  ('been', 'spying'): {'on': 1.0},
#  ('spying', 'on'): {'the': 1.0},
#  ('the', 'slytherin'): {'team': 1.0},
#  ('slytherin', 'team'): {'had': 0.5, 'was': 0.5},
#  ('team', 'had'): {'seen': 1.0},
#  ('had', 'seen'): {'for': 1.0},
#  ('seen', 'for'): {'themselves': 1.0},
#  ('for', 'themselves'): {'the': 1.0},
#  ('themselves', 'the'): {'speed': 1.0},
#  ('the', 'speed'): {'of': 1.0},
#  ('speed', 'of'): {'those': 1.0},
#  ('of', 'those'): {'new': 1.0},
#  ('those', 'new'): {'nimbus': 1.0},
#  ('new', 'nimbus'): {'two': 1.0},
#  ('nimbus', 'two'): {'thousand': 1.0},
#  ('two', 'thousand'): {'and': 1.0},
#  ('thousand', 'and'): {'ones': 1.0},
#  ('and', 'ones'): {'.': 0.5, 'for': 0.5},
#  ('ones', '.'): {'they': 1.0},
#  ('.', 'they'): {'reported': 1.0},
#  ('they', 'reported'): {'that': 1.0},
#  ('reported', 'that'): {'the': 1.0},
#  ('that', 'the'): {'slytherin': 1.0},
#  ('team', 'was'): {'no': 1.0},
#  ('was', 'no'): {'more': 1.0},
#  ('no', 'more'): {'than': 1.0},
#  ('more', 'than'): {'seven': 1.0},
#  ('than', 'seven'): {'greenish': 1.0},
#  ('seven', 'greenish'): {'blurs': 1.0},
#  ('greenish', 'blurs'): {'shooting': 1.0},
#  ('blurs', 'shooting'): {'through': 1.0},
#  ('shooting', 'through'): {'the': 1.0},
#  ('through', 'the'): {'air': 1.0},
#  ('the', 'air'): {'like': 1.0},
#  ('air', 'like'): {'missiles': 1.0},
#  ('like', 'missiles'): {'.': 1.0},
#  ('missiles', '.'): {'as': 1.0},
#  ('.', 'as'): {'harry': 1.0},
#  ('as', 'harry'): {'squelched': 1.0},
#  ('harry', 'squelched'): {'along': 1.0},
#  ('squelched', 'along'): {'the': 1.0},
#  ('along', 'the'): {'deserted': 1.0},
#  ('the', 'deserted'): {'corridor': 1.0},
#  ('deserted', 'corridor'): {'he': 1.0},
#  ('corridor', 'he'): {'came': 1.0},
#  ('he', 'came'): {'across': 1.0},
#  ('came', 'across'): {'somebody': 1.0},
#  ('across', 'somebody'): {'who': 1.0},
#  ('somebody', 'who'): {'looked': 1.0},
#  ('who', 'looked'): {'just': 1.0},
#  ('looked', 'just'): {'as': 1.0},
#  ('just', 'as'): {'preoccupied': 1.0},
#  ('as', 'preoccupied'): {'as': 1.0},
#  ('preoccupied', 'as'): {'he': 1.0},
#  ('as', 'he'): {'was': 0.3333333333333333,
#   'spoke': 0.3333333333333333,
#   'pointed': 0.3333333333333333},
#  ('he', 'was'): {'.': 0.3333333333333333,
#   'pale': 0.3333333333333333,
#   'always': 0.3333333333333333},
#  ('was', '.'): {'nearly': 1.0},
#  ('.', 'nearly'): {'headless': 1.0},
#  ('nearly', 'headless'): {'nick': 1.0},
#  ('headless', 'nick'): {'the': 0.14285714285714285,
#   'starting': 0.14285714285714285,
#   'waved': 0.14285714285714285,
#   'shook': 0.14285714285714285,
#   'stuffed': 0.14285714285714285,
#   'took': 0.14285714285714285,
#   'and': 0.14285714285714285},
#  ('nick', 'the'): {'ghost': 1.0},
#  ('the', 'ghost'): {'of': 1.0},
#  ('ghost', 'of'): {'gryffindor': 1.0},
#  ('of', 'gryffindor'): {'tower': 1.0},
#  ('tower', 'was'): {'staring': 1.0},
#  ('was', 'staring'): {'morosely': 1.0},
#  ('staring', 'morosely'): {'out': 1.0},
#  ('morosely', 'out'): {'ofwindow': 1.0},
#  ('out', 'ofwindow'): {'muttering': 1.0},
#  ('ofwindow', 'muttering'): {'under': 1.0},
#  ('muttering', 'under'): {'his': 1.0},
#  ('under', 'his'): {'breath': 1.0},
#  ('his', 'breath'): {'.': 1.0},
#  ('breath', '.'): {'.': 1.0},
#  ('.', '.'): {'.': 0.5142857142857142,
#   'donfulfill': 0.02857142857142857,
#   'half': 0.02857142857142857,
#   'hello': 0.02857142857142857,
#   'itnot': 0.02857142857142857,
#   'thoughtd': 0.02857142857142857,
#   'frog': 0.02857142857142857,
#   'rat': 0.02857142857142857,
#   '.ve': 0.02857142857142857,
#   'make': 0.02857142857142857,
#   'wherethe': 0.02857142857142857,
#   'yes': 0.02857142857142857,
#   'he': 0.02857142857142857,
#   'harry': 0.02857142857142857,
#   'it': 0.02857142857142857,
#   'befouling': 0.02857142857142857,
#   'suggested': 0.02857142857142857,
#   'dabbing': 0.02857142857142857},
#  ('.', 'donfulfill'): {'their': 1.0},
#  ('donfulfill', 'their'): {'requirements': 1.0},
#  ('their', 'requirements'): {'.': 1.0},
#  ('requirements', '.'): {'.': 0.5, 'with': 0.5},
#  ('.', 'half'): {'an': 1.0},
#  ('half', 'an'): {'inch': 1.0},
#  ('an', 'inch'): {'if': 0.5, 'of': 0.5},
#  ('inch', 'if'): {'that': 1.0},
#  ('if', 'that'): {'.': 1.0},
#  ('that', '.'): {'.': 1.0},
#  ('.', 'hello'): {'nick': 0.5, 'hello': 0.5},
#  ('hello', 'nick'): {'said': 1.0},
#  ('nick', 'said'): {'harry': 1.0},
#  ('said', 'harry'): {'.': 0.6666666666666666,
#   'who': 0.16666666666666666,
#   'backing': 0.16666666666666666},
#  ('harry', '.'): {'hello': 0.25, 'ah': 0.25, 'not': 0.25, 'itonlybit': 0.25},
#  ('hello', 'hello'): {'said': 1.0},
#  ('hello', 'said'): {'nearly': 1.0},
#  ('said', 'nearly'): {'headless': 1.0},
#  ('nick', 'starting'): {'and': 1.0},
#  ('starting', 'and'): {'looking': 1.0},
#  ('and', 'looking'): {'round': 0.5, 'wildly': 0.5},
#  ('looking', 'round'): {'.': 1.0},
#  ('round', '.'): {'he': 1.0},
#  ('.', 'he'): {'woredashing': 0.25,
#   'was': 0.25,
#   'looked': 0.25,
#   'retrievedlarge': 0.25},
#  ('he', 'woredashing'): {'plumed': 1.0},
#  ('woredashing', 'plumed'): {'hat': 1.0},
#  ('plumed', 'hat'): {'on': 1.0},
#  ('hat', 'on'): {'his': 1.0},
#  ('on', 'his'): {'long': 0.3333333333333333,
#   'face': 0.3333333333333333,
#   'desk': 0.3333333333333333},
#  ('his', 'long'): {'curly': 0.5, 'black': 0.5},
#  ('long', 'curly'): {'hair': 1.0},
#  ('curly', 'hair'): {'andtunic': 1.0},
#  ('hair', 'andtunic'): {'withruff': 1.0},
#  ('andtunic', 'withruff'): {'which': 1.0},
#  ('withruff', 'which'): {'concealed': 1.0},
#  ('which', 'concealed'): {'the': 1.0},
#  ('concealed', 'the'): {'fact': 1.0},
#  ('the', 'fact'): {'that': 1.0},
#  ('fact', 'that'): {'his': 1.0},
#  ('that', 'his'): {'neck': 1.0},
#  ('his', 'neck'): {'was': 1.0},
#  ('neck', 'was'): {'almost': 1.0},
#  ('was', 'almost'): {'completely': 1.0},
#  ('almost', 'completely'): {'severed': 1.0},
#  ('completely', 'severed'): {'.': 1.0},
#  ('severed', '.'): {'he': 1.0},
#  ('was', 'pale'): {'as': 1.0},
#  ('pale', 'as'): {'smoke': 1.0},
#  ('as', 'smoke'): {'and': 1.0},
#  ('smoke', 'and'): {'harry': 1.0},
#  ('and', 'harry'): {'could': 1.0},
#  ('harry', 'could'): {'see': 1.0},
#  ('could', 'see'): {'right': 0.5, 'that': 0.5},
#  ('see', 'right'): {'through': 1.0},
#  ('right', 'through'): {'him': 1.0},
#  ('through', 'him'): {'to': 1.0},
#  ('him', 'to'): {'the': 1.0},
#  ('the', 'dark'): {'sky': 1.0},
#  ('dark', 'sky'): {'and': 1.0},
#  ('sky', 'and'): {'torrential': 1.0},
#  ('and', 'torrential'): {'rain': 1.0},
#  ('torrential', 'rain'): {'outside': 1.0},
#  ('rain', 'outside'): {'.': 1.0},
#  ('outside', '.'): {'you': 1.0},
#  ('.', 'you'): {'look': 0.5, 'will': 0.5},
#  ('you', 'look'): {'troubled': 1.0},
#  ('look', 'troubled'): {'young': 1.0},
#  ('troubled', 'young'): {'potter': 1.0},
#  ('young', 'potter'): {'said': 1.0},
#  ('potter', 'said'): {'nick': 1.0},
#  ('said', 'nick'): {'foldingtransparent': 0.5, 'quickly': 0.5},
#  ('nick', 'foldingtransparent'): {'letter': 1.0},
#  ('foldingtransparent', 'letter'): {'as': 1.0},
#  ('letter', 'as'): {'he': 1.0},
#  ('he', 'spoke'): {'and': 1.0},
#  ('spoke', 'and'): {'tucking': 1.0},
#  ('and', 'tucking'): {'it': 1.0},
#  ('tucking', 'it'): {'inside': 1.0},
#  ('it', 'inside'): {'his': 1.0},
#  ('inside', 'his'): {'doublet': 1.0},
#  ('his', 'doublet'): {'.': 1.0},
#  ('doublet', '.'): {'so': 1.0},
#  ('.', 'so'): {'do': 1.0},
#  ('so', 'do'): {'you': 1.0},
#  ('do', 'you'): {'said': 1.0},
#  ('you', 'said'): {'harry': 1.0},
#  ('.', 'ah'): {'nearly': 1.0},
#  ('ah', 'nearly'): {'headless': 1.0},
#  ('nick', 'waved'): {'an': 1.0},
#  ('waved', 'an'): {'elegant': 1.0},
#  ('an', 'elegant'): {'handmatter': 1.0},
#  ('elegant', 'handmatter'): {'of': 1.0},
#  ('handmatter', 'of'): {'no': 1.0},
#  ('of', 'no'): {'importance': 1.0},
#  ('no', 'importance'): {'.': 1.0},
#  ('importance', '.'): {'.': 1.0},
#  ('.', 'itnot'): {'as': 1.0},
#  ('itnot', 'as'): {'thoughreally': 1.0},
#  ('as', 'thoughreally'): {'wanted': 1.0},
#  ('thoughreally', 'wanted'): {'to': 1.0},
#  ('wanted', 'to'): {'join': 1.0},
#  ('to', 'join'): {'.': 0.5, 'the': 0.5},
#  ('join', '.'): {'.': 1.0},
#  ('.', 'thoughtd'): {'apply': 1.0},
#  ('thoughtd', 'apply'): {'but': 1.0},
#  ('apply', 'but'): {'apparentlydonfulfill': 1.0},
#  ('but', 'apparentlydonfulfill'): {'requirements': 1.0},
#  ('apparentlydonfulfill', 'requirements'): {'-': 1.0},
#  ('requirements', '-'): {'in': 1.0},
#  ('-', 'in'): {'spite': 1.0},
#  ('in', 'spite'): {'of': 1.0},
#  ('spite', 'of'): {'his': 1.0},
#  ('of', 'his'): {'airy': 0.3333333333333333,
#   'pocket': 0.3333333333333333,
#   'bulbous': 0.3333333333333333},
#  ('his', 'airy'): {'tone': 1.0},
#  ('airy', 'tone'): {'there': 1.0},
#  ('tone', 'there'): {'waslook': 1.0},
#  ('there', 'waslook'): {'of': 1.0},
#  ('waslook', 'of'): {'great': 1.0},
#  ('of', 'great'): {'bitterness': 1.0},
#  ('great', 'bitterness'): {'on': 1.0},
#  ('bitterness', 'on'): {'his': 1.0},
#  ('his', 'face'): {'.': 1.0},
#  ('face', '.'): {'but': 1.0},
#  ('.', 'but'): {'you': 0.5, 'as': 0.5},
#  ('but', 'you'): {'would': 1.0},
#  ('you', 'would'): {'think': 1.0},
#  ('would', 'think'): {'wouldnyou': 0.5, 'thatgood': 0.5},
#  ('think', 'wouldnyou'): {'he': 1.0},
#  ('wouldnyou', 'he'): {'erupted': 1.0},
#  ('he', 'erupted'): {'suddenly': 1.0},
#  ('erupted', 'suddenly'): {'pulling': 1.0},
#  ('suddenly', 'pulling'): {'the': 1.0},
#  ('pulling', 'the'): {'letter': 1.0},
#  ('the', 'letter'): {'back': 0.5, 'away': 0.5},
#  ('letter', 'back'): {'out': 1.0},
#  ('back', 'out'): {'of': 1.0},
#  ('out', 'of'): {'his': 0.5, 'here': 0.5},
#  ('his', 'pocket'): {'that': 1.0},
#  ('pocket', 'that'): {'getting': 1.0},
#  ('that', 'getting'): {'hit': 1.0},
#  ('getting', 'hit'): {'forty-five': 1.0},
#  ('hit', 'forty-five'): {'times': 1.0},
#  ('forty-five', 'times'): {'in': 1.0},
#  ('times', 'in'): {'the': 1.0},
#  ('in', 'the'): {'neck': 1.0},
#  ('the', 'neck'): {'withblunt': 1.0},
#  ('neck', 'withblunt'): {'axe': 1.0},
#  ('withblunt', 'axe'): {'would': 1.0},
#  ('axe', 'would'): {'qualify': 1.0},
#  ('would', 'qualify'): {'you': 1.0},
#  ('qualify', 'you'): {'to': 1.0},
#  ('you', 'to'): {'join': 1.0},
#  ('join', 'the'): {'headless': 1.0},
#  ('the', 'headless'): {'hunt': 1.0},
#  ('headless', 'hunt'): {'oh': 1.0},
#  ('hunt', 'oh'): {'-': 1.0},
#  ('oh', '-'): {'yes': 1.0},
#  ('-', 'yes'): {'said': 1.0},
#  ('yes', 'said'): {'harry': 1.0},
#  ('harry', 'who'): {'was': 0.5, 'waited': 0.5},
#  ('who', 'was'): {'obviously': 0.5, 'used': 0.5},
#  ('was', 'obviously'): {'supposed': 1.0},
#  ('obviously', 'supposed'): {'to': 1.0},
#  ('supposed', 'to'): {'agree': 1.0},
#  ('to', 'agree'): {'.mean': 1.0},
#  ('agree', '.mean'): {'nobody': 1.0},
#  ('.mean', 'nobody'): {'wishes': 1.0},
#  ('nobody', 'wishes'): {'more': 1.0},
#  ('wishes', 'more'): {'thando': 1.0},
#  ('more', 'thando'): {'that': 1.0},
#  ('thando', 'that'): {'it': 1.0},
#  ('that', 'it'): {'had': 0.5, 'would': 0.5},
#  ('it', 'had'): {'all': 1.0},
#  ('had', 'all'): {'been': 1.0},
#  ('all', 'been'): {'quick': 1.0},
#  ('been', 'quick'): {'and': 1.0},
#  ('quick', 'and'): {'clean': 1.0},
#  ('and', 'clean'): {'and': 1.0},
#  ('clean', 'and'): {'my': 1.0},
#  ('and', 'my'): {'head': 1.0},
#  ('my', 'head'): {'had': 1.0},
#  ('head', 'had'): {'come': 1.0},
#  ('had', 'come'): {'off': 1.0},
#  ('come', 'off'): {'properlymean': 1.0},
#  ('off', 'properlymean'): {'it': 1.0},
#  ('properlymean', 'it'): {'would': 1.0},
#  ('it', 'would'): {'have': 0.5, 'be': 0.5},
#  ('would', 'have'): {'saved': 1.0},
#  ('have', 'saved'): {'megreat': 1.0},
#  ('saved', 'megreat'): {'deal': 1.0},
#  ('megreat', 'deal'): {'of': 1.0},
#  ('deal', 'of'): {'pain': 1.0},
#  ('of', 'pain'): {'and': 1.0},
#  ('pain', 'and'): {'ridicule': 1.0},
#  ('and', 'ridicule'): {'.': 1.0},
#  ('ridicule', '.'): {'however': 1.0},
#  ('.', 'however'): {'-': 1.0},
#  ('however', '-'): {'nearly': 1.0},
#  ('-', 'nearly'): {'headless': 1.0},
#  ('nick', 'shook'): {'his': 1.0},
#  ('shook', 'his'): {'letter': 1.0},
#  ('his', 'letter'): {'open': 1.0},
#  ('letter', 'open'): {'and': 1.0},
#  ('open', 'and'): {'read': 1.0},
#  ('and', 'read'): {'furiously': 1.0},
#  ('read', 'furiously'): {'we': 1.0},
#  ('furiously', 'we'): {'can': 1.0},
#  ('we', 'can'): {'only': 0.5, 'get': 0.5},
#  ('can', 'only'): {'accept': 1.0},
#  ('only', 'accept'): {'huntsmen': 1.0},
#  ('accept', 'huntsmen'): {'whose': 1.0},
#  ('huntsmen', 'whose'): {'heads': 1.0},
#  ('whose', 'heads'): {'have': 1.0},
#  ('heads', 'have'): {'parted': 1.0},
#  ('have', 'parted'): {'company': 1.0},
#  ('parted', 'company'): {'with': 1.0},
#  ('company', 'with'): {'their': 1.0},
#  ('with', 'their'): {'bodies': 1.0},
#  ('their', 'bodies'): {'.': 1.0},
#  ('bodies', '.'): {'you': 1.0},
#  ('you', 'will'): {'appreciate': 1.0},
#  ('will', 'appreciate'): {'that': 1.0},
#  ('appreciate', 'that'): {'it': 1.0},
#  ('would', 'be'): {'impossible': 1.0},
#  ('be', 'impossible'): {'otherwise': 1.0},
#  ('impossible', 'otherwise'): {'for': 1.0},
#  ('otherwise', 'for'): {'members': 1.0},
#  ('for', 'members'): {'to': 1.0},
#  ('members', 'to'): {'participate': 1.0},
#  ('to', 'participate'): {'in': 1.0},
#  ('participate', 'in'): {'hunt': 1.0},
#  ('in', 'hunt'): {'activities': 1.0},
#  ('hunt', 'activities'): {'such': 1.0},
#  ('activities', 'such'): {'as': 1.0},
#  ('such', 'as'): {'horseback': 1.0},
#  ('as', 'horseback'): {'head-juggling': 1.0},
#  ('horseback', 'head-juggling'): {'and': 1.0},
#  ('head-juggling', 'and'): {'head': 1.0},
#  ('and', 'head'): {'polo': 1.0},
#  ('head', 'polo'): {'.': 1.0},
#  ('polo', '.'): {'it': 1.0},
#  ('.', 'it'): {'was': 0.75, 'is': 0.25},
#  ('it', 'is'): {'with': 1.0},
#  ('is', 'with'): {'the': 1.0},
#  ('the', 'greatest'): {'regret': 1.0},
#  ('greatest', 'regret'): {'therefore': 1.0},
#  ('regret', 'therefore'): {'thatmust': 1.0},
#  ('therefore', 'thatmust'): {'inform': 1.0},
#  ('thatmust', 'inform'): {'you': 1.0},
#  ('inform', 'you'): {'that': 1.0},
#  ('you', 'that'): {'you': 1.0},
#  ('that', 'you'): {'do': 1.0},
#  ('you', 'do'): {'not': 1.0},
#  ('do', 'not'): {'fulfill': 1.0},
#  ('not', 'fulfill'): {'our': 1.0},
#  ('fulfill', 'our'): {'requirements': 1.0},
#  ('our', 'requirements'): {'.': 1.0},
#  ('.', 'with'): {'very': 1.0},
#  ('with', 'very'): {'best': 1.0},
#  ('very', 'best'): {'wishes': 1.0},
#  ('best', 'wishes'): {'sir': 1.0},
#  ('wishes', 'sir'): {'patrick': 1.0},
#  ('sir', 'patrick'): {'delaney-podmore': 1.0},
#  ('patrick', 'delaney-podmore'): {'.': 1.0},
#  ('delaney-podmore', '.'): {'fuming': 1.0},
#  ('.', 'fuming'): {'nearly': 1.0},
#  ('fuming', 'nearly'): {'headless': 1.0},
#  ('nick', 'stuffed'): {'the': 1.0},
#  ('stuffed', 'the'): {'letter': 1.0},
#  ('letter', 'away'): {'.': 1.0},
#  ('away', '.'): {'half': 1.0},
#  ('inch', 'of'): {'skin': 1.0},
#  ('of', 'skin'): {'and': 1.0},
#  ('and', 'sinew'): {'holding': 1.0},
#  ('sinew', 'holding'): {'my': 1.0},
#  ('holding', 'my'): {'neck': 1.0},
#  ('my', 'neck'): {'on': 1.0},
#  ('neck', 'on'): {'harry': 1.0},
#  ('on', 'harry'): {'most': 1.0},
#  ('harry', 'most'): {'people': 1.0},
#  ('most', 'people'): {'would': 1.0},
#  ('people', 'would'): {'think': 1.0},
#  ('think', 'thatgood'): {'and': 1.0},
#  ('thatgood', 'and'): {'beheaded': 1.0},
#  ('and', 'beheaded'): {'but': 1.0},
#  ('beheaded', 'but'): {'oh': 1.0},
#  ('but', 'oh'): {'no': 1.0},
#  ('oh', 'no'): {'itnot': 1.0},
#  ('no', 'itnot'): {'enough': 1.0},
#  ('itnot', 'enough'): {'for': 1.0},
#  ('enough', 'for'): {'sir': 1.0},
#  ('for', 'sir'): {'properly': 1.0},
#  ('sir', 'properly'): {'decapitated-podmore': 1.0},
#  ('properly', 'decapitated-podmore'): {'.': 1.0},
#  ('decapitated-podmore', '.'): {'nearly': 1.0},
#  ('nick', 'took'): {'several': 1.0},
#  ('took', 'several'): {'deep': 1.0},
#  ('several', 'deep'): {'breaths': 1.0},
#  ('deep', 'breaths'): {'and': 1.0},
#  ('breaths', 'and'): {'then': 1.0},
#  ('and', 'then'): {'said': 1.0},
#  ('then', 'said'): {'infar': 1.0},
#  ('said', 'infar'): {'calmer': 1.0},
#  ('infar', 'calmer'): {'tone': 1.0},
#  ('calmer', 'tone'): {'so': 1.0},
#  ('tone', 'so'): {'-': 1.0},
#  ('so', '-'): {'whatbothering': 1.0},
#  ('-', 'whatbothering'): {'you': 1.0},
#  ('whatbothering', 'you'): {'anythingcan': 1.0},
#  ('you', 'anythingcan'): {'do': 1.0},
#  ('anythingcan', 'do'): {'no': 1.0},
#  ('do', 'no'): {'said': 1.0},
#  ('no', 'said'): {'harry': 1.0},
#  ('.', 'not'): {'unless': 1.0},
#  ('not', 'unless'): {'you': 1.0},
#  ('unless', 'you'): {'know': 1.0},
#  ('you', 'know'): {'where': 1.0},
#  ('know', 'where'): {'we': 1.0},
#  ('where', 'we'): {'can': 1.0},
#  ('can', 'get'): {'seven': 1.0},
#  ('get', 'seven'): {'free': 1.0},
#  ('seven', 'free'): {'nimbus': 1.0},
#  ('free', 'nimbus'): {'two': 1.0},
#  ('ones', 'for'): {'our': 1.0},
#  ('for', 'our'): {'match': 1.0},
#  ('our', 'match'): {'against': 1.0},
#  ('match', 'against'): {'sly': 1.0},
#  ('against', 'sly'): {'-': 1.0},
#  ('sly', '-'): {'the': 1.0},
#  ('-', 'the'): {'rest': 1.0},
#  ('the', 'rest'): {'of': 1.0},
#  ('rest', 'of'): {'harrysentence': 1.0},
#  ('of', 'harrysentence'): {'was': 1.0},
#  ('harrysentence', 'was'): {'drowned': 1.0},
#  ('was', 'drowned'): {'out': 1.0},
#  ('drowned', 'out'): {'byhigh-pitched': 1.0},
#  ('out', 'byhigh-pitched'): {'mewling': 1.0},
#  ('byhigh-pitched', 'mewling'): {'from': 1.0},
#  ('mewling', 'from'): {'somewhere': 1.0},
#  ('from', 'somewhere'): {'near': 1.0},
#  ('somewhere', 'near'): {'his': 1.0},
#  ('near', 'his'): {'ankles': 1.0},
#  ('his', 'ankles'): {'.': 1.0},
#  ('ankles', '.'): {'he': 1.0},
#  ('he', 'looked'): {'down': 1.0},
#  ('looked', 'down'): {'and': 1.0},
#  ('down', 'and'): {'found': 1.0},
#  ('and', 'found'): {'himself': 1.0},
#  ('found', 'himself'): {'gazing': 1.0},
#  ('himself', 'gazing'): {'intopair': 1.0},
#  ('gazing', 'intopair'): {'of': 1.0},
#  ('intopair', 'of'): {'lamp-like': 1.0},
#  ('of', 'lamp-like'): {'yellow': 1.0},
#  ('lamp-like', 'yellow'): {'eyes': 1.0},
#  ('yellow', 'eyes'): {'.': 1.0},
#  ('eyes', '.'): {'it': 1.0},
#  ('it', 'was'): {'mrs': 0.3333333333333333,
#   'common': 0.3333333333333333,
#   'onlybit': 0.3333333333333333},
#  ('was', 'mrs'): {'.': 1.0},
#  ('mrs', '.'): {'norris': 1.0},
#  ('.', 'norris'): {'the': 0.5, 'but': 0.5},
#  ('norris', 'the'): {'skeletal': 1.0},
#  ('the', 'skeletal'): {'gray': 1.0},
#  ('skeletal', 'gray'): {'cat': 1.0},
#  ('gray', 'cat'): {'who': 1.0},
#  ('cat', 'who'): {'was': 1.0},
#  ('was', 'used'): {'by': 1.0},
#  ('used', 'by'): {'the': 1.0},
#  ('by', 'the'): {'caretaker': 0.5, 'mysterious': 0.5},
#  ('the', 'caretaker'): {'argus': 1.0},
#  ('caretaker', 'argus'): {'filch': 1.0},
#  ('argus', 'filch'): {'assort': 0.5, 'burst': 0.5},
#  ('filch', 'assort'): {'of': 1.0},
#  ('assort', 'of'): {'deputy': 1.0},
#  ('of', 'deputy'): {'in': 1.0},
#  ('deputy', 'in'): {'his': 1.0},
#  ('in', 'his'): {'endless': 1.0},
#  ('his', 'endless'): {'battle': 1.0},
#  ('endless', 'battle'): {'against': 1.0},
#  ('battle', 'against'): {'students': 1.0},
#  ('against', 'students'): {'.': 1.0},
#  ('.', 'youbetter'): {'get': 1.0},
#  ('youbetter', 'get'): {'out': 1.0},
#  ('get', 'out'): {'of': 1.0},
#  ('of', 'here'): {'harry': 1.0},
#  ('here', 'harry'): {'said': 1.0},
#  ('harry', 'said'): {'nick': 1.0},
#  ('nick', 'quickly'): {'.': 1.0},
#  ('quickly', '.'): {'filch': 1.0},
#  ('.', 'filch'): {'isningood': 0.5, 'grabbedquill': 0.5},
#  ('filch', 'isningood'): {'mood': 1.0},
#  ('isningood', 'mood'): {'-': 1.0},
#  ('mood', '-'): {'hegot': 1.0},
#  ('-', 'hegot'): {'the': 1.0},
#  ('hegot', 'the'): {'flu': 1.0},
#  ('the', 'flu'): {'and': 1.0},
#  ('flu', 'and'): {'some': 1.0},
#  ('and', 'some'): {'third': 1.0},
#  ('some', 'third'): {'years': 1.0},
#  ('third', 'years'): {'accidentally': 1.0},
#  ('years', 'accidentally'): {'plastered': 1.0},
#  ('accidentally', 'plastered'): {'frog': 1.0},
#  ('plastered', 'frog'): {'brains': 1.0},
#  ('frog', 'brains'): {'all': 0.5, '.': 0.5},
#  ('brains', 'all'): {'over': 1.0},
#  ('all', 'over'): {'the': 1.0},
#  ('the', 'ceiling'): {'in': 0.3333333333333333,
#   '.': 0.3333333333333333,
#   'of': 0.3333333333333333},
#  ('ceiling', 'in'): {'dungeon': 1.0},
#  ('in', 'dungeon'): {'five': 1.0},
#  ('dungeon', 'five'): {'.': 1.0},
#  ('five', '.'): {'hebeen': 1.0},
#  ('.', 'hebeen'): {'cleaning': 1.0},
#  ('hebeen', 'cleaning'): {'all': 1.0},
#  ('cleaning', 'all'): {'morning': 1.0},
#  ('all', 'morning'): {'and': 1.0},
#  ('morning', 'and'): {'if': 1.0},
#  ('and', 'if'): {'he': 1.0},
#  ('if', 'he'): {'sees': 1.0},
#  ('he', 'sees'): {'you': 1.0},
#  ('sees', 'you'): {'dripping': 1.0},
#  ('you', 'dripping'): {'mud': 1.0},
#  ('dripping', 'mud'): {'all': 1.0},
#  ('mud', 'all'): {'over': 1.0},
#  ('the', 'place'): {'-': 0.5, '.': 0.5},
#  ('place', '-'): {'right': 1.0},
#  ('-', 'right'): {'said': 1.0},
#  ('right', 'said'): {'harry': 1.0},
#  ('harry', 'backing'): {'away': 1.0},
#  ('backing', 'away'): {'from': 1.0},
#  ('away', 'from'): {'the': 1.0},
#  ('the', 'accusing'): {'stare': 1.0},
#  ('accusing', 'stare'): {'of': 1.0},
#  ('stare', 'of'): {'mrs': 1.0},
#  ('of', 'mrs'): {'.': 1.0},
#  ('norris', 'but'): {'not': 1.0},
#  ('but', 'not'): {'quickly': 1.0},
#  ('not', 'quickly'): {'enough': 1.0},
#  ('quickly', 'enough'): {'.': 1.0},
#  ('enough', '.'): {'drawn': 1.0},
#  ('.', 'drawn'): {'to': 1.0},
#  ('drawn', 'to'): {'the': 1.0},
#  ('the', 'spot'): {'by': 1.0},
#  ('spot', 'by'): {'the': 1.0},
#  ('the', 'mysterious'): {'power': 1.0},
#  ('mysterious', 'power'): {'that': 1.0},
#  ('power', 'that'): {'seemed': 1.0},
#  ('that', 'seemed'): {'to': 1.0},
#  ('seemed', 'to'): {'connect': 1.0},
#  ('to', 'connect'): {'him': 1.0},
#  ('connect', 'him'): {'with': 1.0},
#  ('him', 'with'): {'his': 1.0},
#  ('with', 'his'): {'foul': 1.0},
#  ('his', 'foul'): {'cat': 1.0},
#  ('foul', 'cat'): {'argus': 1.0},
#  ('cat', 'argus'): {'filch': 1.0},
#  ('filch', 'burst'): {'suddenly': 1.0},
#  ('burst', 'suddenly'): {'throughtapestry': 1.0},
#  ('suddenly', 'throughtapestry'): {'to': 1.0},
#  ('throughtapestry', 'to'): {'harryright': 1.0},
#  ('to', 'harryright'): {'wheezing': 1.0},
#  ('harryright', 'wheezing'): {'and': 1.0},
#  ('wheezing', 'and'): {'looking': 1.0},
#  ('looking', 'wildly'): {'about': 1.0},
#  ('wildly', 'about'): {'for': 1.0},
#  ('about', 'for'): {'the': 1.0},
#  ('for', 'the'): {'rule-breaker': 1.0},
#  ('the', 'rule-breaker'): {'.': 1.0},
#  ('rule-breaker', '.'): {'there': 1.0},
#  ('.', 'there'): {'wasthick': 1.0},
#  ('there', 'wasthick'): {'tartan': 1.0},
#  ('wasthick', 'tartan'): {'scarf': 1.0},
#  ('tartan', 'scarf'): {'bound': 1.0},
#  ('scarf', 'bound'): {'around': 1.0},
#  ('bound', 'around'): {'his': 1.0},
#  ('around', 'his'): {'head': 1.0},
#  ('his', 'head'): {'and': 1.0},
#  ('head', 'and'): {'his': 1.0},
#  ('and', 'his'): {'nose': 1.0},
#  ('his', 'nose'): {'was': 1.0},
#  ('nose', 'was'): {'unusually': 1.0},
#  ('was', 'unusually'): {'purple': 1.0},
#  ('unusually', 'purple'): {'.': 1.0},
#  ('purple', '.'): {'filth': 1.0},
#  ('.', 'filth'): {'he': 1.0},
#  ('filth', 'he'): {'shouted': 1.0},
#  ('he', 'shouted'): {'his': 1.0},
#  ('shouted', 'his'): {'jowls': 1.0},
#  ('his', 'jowls'): {'aquiver': 1.0},
#  ('jowls', 'aquiver'): {'his': 1.0},
#  ('aquiver', 'his'): {'eyes': 1.0},
#  ('his', 'eyes'): {'popping': 1.0},
#  ('eyes', 'popping'): {'alarmingly': 1.0},
#  ('popping', 'alarmingly'): {'as': 1.0},
#  ('alarmingly', 'as'): {'he': 1.0},
#  ('he', 'pointed'): {'at': 1.0},
#  ('pointed', 'at'): {'the': 1.0},
#  ('the', 'muddy'): {'puddle': 1.0},
#  ('muddy', 'puddle'): {'that': 1.0},
#  ('puddle', 'that'): {'had': 1.0},
#  ('that', 'had'): {'dripped': 1.0},
#  ('had', 'dripped'): {'from': 1.0},
#  ('dripped', 'from'): {'harryquidditch': 1.0},
#  ('from', 'harryquidditch'): {'robes': 1.0},
#  ('harryquidditch', 'robes'): {'.': 1.0},
#  ('robes', '.'): {'mess': 1.0},
#  ('.', 'mess'): {'and': 1.0},
#  ('mess', 'and'): {'muck': 1.0},
#  ('and', 'muck'): {'everywhereve': 1.0},
#  ('muck', 'everywhereve'): {'had': 1.0},
#  ('everywhereve', 'had'): {'enough': 1.0},
#  ('had', 'enough'): {'of': 1.0},
#  ('enough', 'of'): {'ittell': 0.5, 'it': 0.5},
#  ('of', 'ittell'): {'you': 1.0},
#  ('ittell', 'you'): {'follow': 1.0},
#  ('you', 'follow'): {'me': 1.0},
#  ('follow', 'me'): {'potter': 1.0},
#  ('me', 'potter'): {'so': 1.0},
#  ('potter', 'so'): {'harry': 1.0},
#  ('so', 'harry'): {'wavedgloomy': 1.0},
#  ('harry', 'wavedgloomy'): {'good-bye': 1.0},
#  ('wavedgloomy', 'good-bye'): {'to': 1.0},
#  ('good-bye', 'to'): {'nearly': 1.0},
#  ('to', 'nearly'): {'headless': 1.0},
#  ('nick', 'and'): {'followed': 1.0},
#  ('and', 'followed'): {'filch': 1.0},
#  ('followed', 'filch'): {'back': 1.0},
#  ('filch', 'back'): {'downstairs': 1.0},
#  ('back', 'downstairs'): {'doubling': 1.0},
#  ('downstairs', 'doubling'): {'the': 1.0},
#  ('doubling', 'the'): {'number': 1.0},
#  ('the', 'number'): {'of': 1.0},
#  ('number', 'of'): {'muddy': 1.0},
#  ('of', 'muddy'): {'footprints': 1.0},
#  ('muddy', 'footprints'): {'on': 1.0},
#  ('footprints', 'on'): {'the': 1.0},
#  ('the', 'floor'): {'.': 1.0},
#  ('floor', '.'): {'harry': 1.0},
#  ('.', 'harry'): {'had': 0.5, 'potter': 0.5},
#  ('harry', 'had'): {'never': 1.0},
#  ('had', 'never'): {'been': 1.0},
#  ('never', 'been'): {'inside': 1.0},
#  ('been', 'inside'): {'filchoffice': 1.0},
#  ('inside', 'filchoffice'): {'before': 1.0},
#  ('filchoffice', 'before'): {'it': 1.0},
#  ('before', 'it'): {'wasplace': 1.0},
#  ('it', 'wasplace'): {'most': 1.0},
#  ('wasplace', 'most'): {'students': 1.0},
#  ('most', 'students'): {'avoided': 1.0},
#  ('students', 'avoided'): {'.': 1.0},
#  ('avoided', '.'): {'the': 1.0},
#  ('the', 'room'): {'was': 1.0},
#  ('room', 'was'): {'dingy': 1.0},
#  ('was', 'dingy'): {'and': 1.0},
#  ('dingy', 'and'): {'windowless': 1.0},
#  ('and', 'windowless'): {'lit': 1.0},
#  ('windowless', 'lit'): {'bysingle': 1.0},
#  ('lit', 'bysingle'): {'oil': 1.0},
#  ('bysingle', 'oil'): {'lamp': 1.0},
#  ('oil', 'lamp'): {'dangling': 1.0},
#  ('lamp', 'dangling'): {'from': 1.0},
#  ('dangling', 'from'): {'the': 1.0},
#  ('the', 'low'): {'ceiling': 1.0},
#  ('low', 'ceiling'): {'.faint': 1.0},
#  ('ceiling', '.faint'): {'smell': 1.0},
#  ('.faint', 'smell'): {'of': 1.0},
#  ('smell', 'of'): {'fried': 1.0},
#  ('of', 'fried'): {'fish': 1.0},
#  ('fried', 'fish'): {'lingered': 1.0},
#  ('fish', 'lingered'): {'about': 1.0},
#  ('lingered', 'about'): {'the': 1.0},
#  ('about', 'the'): {'place': 1.0},
#  ('place', '.'): {'wooden': 1.0},
#  ('.', 'wooden'): {'filing': 1.0},
#  ('wooden', 'filing'): {'cabinets': 1.0},
#  ('filing', 'cabinets'): {'stood': 1.0},
#  ('cabinets', 'stood'): {'around': 1.0},
#  ('stood', 'around'): {'the': 1.0},
#  ('around', 'the'): {'walls': 1.0},
#  ('the', 'walls'): {'from': 1.0},
#  ('walls', 'from'): {'their': 1.0},
#  ('from', 'their'): {'labels': 1.0},
#  ('their', 'labels'): {'harry': 1.0},
#  ('labels', 'harry'): {'could': 1.0},
#  ('see', 'that'): {'they': 1.0},
#  ('that', 'they'): {'contained': 1.0},
#  ('they', 'contained'): {'details': 1.0},
#  ('contained', 'details'): {'of': 1.0},
#  ('details', 'of'): {'every': 1.0},
#  ('of', 'every'): {'pupil': 1.0},
#  ('every', 'pupil'): {'filch': 1.0},
#  ('pupil', 'filch'): {'had': 1.0},
#  ('filch', 'had'): {'ever': 1.0},
#  ('had', 'ever'): {'punished': 1.0},
#  ('ever', 'punished'): {'.': 1.0},
#  ('punished', '.'): {'fred': 1.0},
#  ('george', 'weasley'): {'had': 1.0},
#  ('weasley', 'had'): {'an': 1.0},
#  ('had', 'an'): {'entire': 1.0},
#  ('an', 'entire'): {'drawer': 1.0},
#  ('entire', 'drawer'): {'to': 1.0},
#  ('drawer', 'to'): {'themselves': 1.0},
#  ('to', 'themselves'): {'.highly': 1.0},
#  ('themselves', '.highly'): {'polished': 1.0},
#  ('.highly', 'polished'): {'collection': 1.0},
#  ('polished', 'collection'): {'of': 1.0},
#  ('collection', 'of'): {'chains': 1.0},
#  ('of', 'chains'): {'and': 1.0},
#  ('chains', 'and'): {'manacles': 1.0},
#  ('and', 'manacles'): {'hung': 1.0},
#  ('manacles', 'hung'): {'on': 1.0},
#  ('hung', 'on'): {'the': 1.0},
#  ('the', 'wall'): {'behind': 1.0},
#  ('wall', 'behind'): {'filchdesk': 1.0},
#  ('behind', 'filchdesk'): {'.': 1.0},
#  ('filchdesk', '.'): {'it': 1.0},
#  ('was', 'common'): {'knowledge': 1.0},
#  ('common', 'knowledge'): {'that': 1.0},
#  ('knowledge', 'that'): {'he': 1.0},
#  ('that', 'he'): {'was': 1.0},
#  ('was', 'always'): {'begging': 1.0},
#  ('always', 'begging'): {'dumbledore': 1.0},
#  ('begging', 'dumbledore'): {'to': 1.0},
#  ('dumbledore', 'to'): {'let': 1.0},
#  ('to', 'let'): {'him': 1.0},
#  ('let', 'him'): {'suspend': 1.0},
#  ('him', 'suspend'): {'students': 1.0},
#  ('suspend', 'students'): {'by': 1.0},
#  ('students', 'by'): {'their': 1.0},
#  ('by', 'their'): {'ankles': 1.0},
#  ('their', 'ankles'): {'from': 1.0},
#  ('ankles', 'from'): {'the': 1.0},
#  ('ceiling', '.'): {'filch': 1.0},
#  ('filch', 'grabbedquill'): {'frompot': 1.0},
#  ('grabbedquill', 'frompot'): {'on': 1.0},
#  ('frompot', 'on'): {'his': 1.0},
#  ('his', 'desk'): {'and': 0.5, 'drawer': 0.5},
#  ('desk', 'and'): {'began': 1.0},
#  ('and', 'began'): {'shuffling': 1.0},
#  ('began', 'shuffling'): {'around': 1.0},
#  ('shuffling', 'around'): {'looking': 1.0},
#  ('around', 'looking'): {'for': 1.0},
#  ('looking', 'for'): {'parchment': 1.0},
#  ('for', 'parchment'): {'.': 1.0},
#  ('parchment', '.'): {'dung': 1.0},
#  ('.', 'dung'): {'he': 1.0},
#  ('dung', 'he'): {'muttered': 1.0},
#  ('he', 'muttered'): {'furiously': 1.0},
#  ('muttered', 'furiously'): {'great': 1.0},
#  ('furiously', 'great'): {'sizzling': 1.0},
#  ('great', 'sizzling'): {'dragon': 1.0},
#  ('sizzling', 'dragon'): {'bogies': 1.0},
#  ('dragon', 'bogies'): {'.': 1.0},
#  ('bogies', '.'): {'.': 1.0},
#  ('.', 'frog'): {'brains': 1.0},
#  ('brains', '.'): {'.': 1.0},
#  ('.', 'rat'): {'intestines': 1.0},
#  ('rat', 'intestines'): {'.': 1.0},
#  ('intestines', '.'): {'.': 1.0},
#  ('.', '.ve'): {'had': 1.0},
#  ('.ve', 'had'): {'enough': 1.0},
#  ('of', 'it'): {'.': 1.0},
#  ('it', '.'): {'.': 1.0},
#  ('.', 'make'): {'an': 1.0},
#  ('make', 'an'): {'example': 1.0},
#  ('an', 'example'): {'.': 1.0},
#  ('example', '.'): {'.': 1.0},
#  ('.', 'wherethe'): {'form': 1.0},
#  ('wherethe', 'form'): {'.': 1.0},
#  ('form', '.'): {'.': 1.0},
#  ('.', 'yes'): {'.': 1.0},
#  ('yes', '.'): {'.': 1.0},
#  ('he', 'retrievedlarge'): {'roll': 1.0},
#  ('retrievedlarge', 'roll'): {'of': 1.0},
#  ('roll', 'of'): {'parchment': 1.0},
#  ('of', 'parchment'): {'from': 1.0},
#  ('parchment', 'from'): {'his': 1.0},
#  ('from', 'his'): {'desk': 1.0},
#  ('desk', 'drawer'): {'and': 1.0},
#  ('drawer', 'and'): {'stretched': 1.0},
#  ('and', 'stretched'): {'it': 1.0},
#  ('stretched', 'it'): {'out': 1.0},
#  ('it', 'out'): {'in': 1.0},
#  ('out', 'in'): {'front': 1.0},
#  ('in', 'front'): {'of': 1.0},
#  ('front', 'of'): {'him': 1.0},
#  ('of', 'him'): {'dipping': 1.0},
#  ('him', 'dipping'): {'his': 1.0},
#  ('dipping', 'his'): {'long': 1.0},
#  ('long', 'black'): {'quill': 1.0},
#  ('black', 'quill'): {'into': 1.0},
#  ('quill', 'into'): {'the': 1.0},
#  ('the', 'ink'): {'pot': 1.0},
#  ('ink', 'pot'): {'.': 1.0},
#  ('pot', '.'): {'name': 1.0},
#  ('.', 'name'): {'.': 1.0},
#  ('name', '.'): {'.': 1.0},
#  ('harry', 'potter'): {'.': 1.0},
#  ('potter', '.'): {'crime': 1.0},
#  ('.', 'crime'): {'.': 1.0},
#  ('crime', '.'): {'.': 1.0},
#  ('was', 'onlybit'): {'of': 1.0},
#  ('onlybit', 'of'): {'mud': 1.0},
#  ('of', 'mud'): {'said': 0.5, 'to': 0.5},
#  ('mud', 'said'): {'harry': 1.0},
#  ('.', 'itonlybit'): {'of': 1.0},
#  ('itonlybit', 'of'): {'mud': 1.0},
#  ('mud', 'to'): {'you': 1.0},
#  ('to', 'you'): {'boy': 1.0},
#  ('you', 'boy'): {'but': 1.0},
#  ('boy', 'but'): {'to': 1.0},
#  ('but', 'to'): {'me': 1.0},
#  ('to', 'me'): {'itan': 1.0},
#  ('me', 'itan'): {'extra': 1.0},
#  ('itan', 'extra'): {'hour': 1.0},
#  ('extra', 'hour'): {'scrubbing': 1.0},
#  ('hour', 'scrubbing'): {'shouted': 1.0},
#  ('scrubbing', 'shouted'): {'filchdrip': 1.0},
#  ('shouted', 'filchdrip'): {'shivering': 1.0},
#  ('filchdrip', 'shivering'): {'unpleasantly': 1.0},
#  ('shivering', 'unpleasantly'): {'at': 1.0},
#  ('unpleasantly', 'at'): {'the': 0.5, 'harry': 0.5},
#  ('the', 'end'): {'of': 1.0},
#  ('end', 'of'): {'his': 1.0},
#  ('his', 'bulbous'): {'nose': 1.0},
#  ('bulbous', 'nose'): {'.': 1.0},
#  ('nose', '.'): {'crime': 1.0},
#  ('.', 'befouling'): {'the': 1.0},
#  ('befouling', 'the'): {'castle': 1.0},
#  ('.', 'suggested'): {'sentence': 1.0},
#  ('suggested', 'sentence'): {'.': 1.0},
#  ('sentence', '.'): {'.': 1.0},
#  ('.', 'dabbing'): {'at': 1.0},
#  ('dabbing', 'at'): {'his': 1.0},
#  ('at', 'his'): {'streaming': 1.0},
#  ('his', 'streaming'): {'nose': 1.0},
#  ('streaming', 'nose'): {'filch': 1.0},
#  ('nose', 'filch'): {'squinted': 1.0},
#  ('filch', 'squinted'): {'unpleasantly': 1.0},
#  ('squinted', 'unpleasantly'): {'at': 1.0},
#  ('at', 'harry'): {'who': 1.0},
#  ('who', 'waited'): {'with': 1.0},
#  ('waited', 'with'): {'bated': 1.0},
#  ('with', 'bated'): {'breath': 1.0},
#  ('bated', 'breath'): {'for': 1.0},
#  ('breath', 'for'): {'his': 1.0},
#  ('for', 'his'): {'sentence': 1.0},
#  ('his', 'sentence'): {'to': 1.0},
#  ('sentence', 'to'): {'fall': 1.0},
#  ('to', 'fall'): {'.': 1.0},
#  ('fall', '.'): {'but': 1.0},
#  ('but', 'as'): {'filch': 1.0},
#  ('as', 'filch'): {'lowered': 1.0},
#  ('filch', 'lowered'): {'his': 1.0},
#  ...}
